# %%
import json
import os
import pandas as pd
import numpy as np
from buckaroo.buckaroo_widget import BuckarooWidget
import requests

# %%
gbfs_df = pd.read_csv("/Users/paddy/Downloads/gbfs-systems.csv")
BuckarooWidget(gbfs_df)
# Out:
# BuckarooWidget(commandConfig={'argspecs': {'dropcol': [None], 'to_datetime': [None], 'safeint': [None], 'filln…

# %%
gbfs_df['Auto-Discovery URL'][0]

# %%
ab = requests.get('https://dubai.publicbikesystem.net/customer/gbfs/v2/en/station_information')
bc = json.loads(ab.text)
BuckarooWidget(pd.DataFrame(bc['data']['stations']))

# %%
system_data = json.loads(requests.get('https://dubai.publicbikesystem.net/customer/gbfs/v2/gbfs.json').text)
system_data['data']['en']['feeds']

# %%
# !mkdir -p  ~/code/closest-bike/raw-json

# %%
# !pwd

# %%
base_dir = "/Users/paddy/code/closest-bike/raw-json"
def get_system_data(index, url):
    try:
        raw_data = json.loads(requests.get(url).text)
        actual_data = raw_data['data']['en']['feeds']
        open("%s/feeds-%d.json" % (base_dir, index), "w").write(json.dumps(actual_data))
    except Exception as e:
        print(index, e)

# %%
from multiprocessing.pool import ThreadPool as Pool

# %%
def f(arg):
    print("arg", arg)
    get_system_data(*arg)
with Pool(30) as p:
    #print(p.map(f, [1, 2, 3]))
    p.map(f, enumerate(gbfs_df['Auto-Discovery URL']))
# Out:
# argarg (7, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ka/gbfs.json')
#  (0, 'https://dubai.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (14, 'https://mds-global-adl-cbd.neuron-mobility.com/gbfs/2/')
# arg (21, 'https://mds-global-hba.neuron-mobility.com/gbfs/2/')
# arg (28, 'https://aruba.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (35, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_gh/gbfs.json')
# arg (42, 'https://data.lime.bike/api/partners/v2/gbfs/antwerp/gbfs.json')
# arg (49, 'https://rec.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (56, 'https://saguenay.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (63, 'https://gbfs.hopr.city/api/gbfs/22/')
# arg (70, 'https://mds-global-ard.neuron-mobility.com/gbfs/2/')
# arg (77, 'https://mds-global-yve.neuron-mobility.com/gbfs/2/')
# arg (84, 'https://gbfs.hopr.city/api/gbfs/13')
# arg (91, 'https://mds.bird.co/gbfs/v2/public/zurich/gbfs.json')
# arg (98, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_yverdon-les-bains/gbfs.json')
# arg (105, 'https://bogota.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (112, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_th/gbfs.json')
# arg (119, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tj/gbfs.json')
# arg (126, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tt/gbfs.json')
# arg (133, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_berlin/gbfs.json')
# arg (140, 'https://nitro.openvelo.org/aachen/felyx/v2/gbfs.json')
# arg (147, 'https://data.lime.bike/api/partners/v2/gbfs/hamburg/gbfs.json')
# arg (154, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_um/gbfs.json')
# arg (161, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ng/gbfs.json')
# arg (168, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_nn/gbfs.json')
# arg (175, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dz/gbfs.json')
# arg (182, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_sf/gbfs.json')
# arg (189, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_vn/gbfs.json')
# arg (196, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_bandholm/gbfs.json')
# arg (203, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_klampenborg/gbfs.json')
# arg (57, 'https://quebec.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (29, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bj/gbfs.json')
# arg (148, 'https://mds.linkyour.city/gbfs/de_nuremberg/gbfs.json')
# arg (43, 'https://data.lime.bike/api/partners/v2/gbfs/brussels/gbfs.json')
# arg (50, 'https://poa.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (92, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_ge/gbfs')
# arg (106, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cy/gbfs.json')
# arg (99, 'https://data.lime.bike/api/partners/v2/gbfs/opfikon/gbfs.json')
# arg (197, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_copenhagen/gbfs.json')
# arg (204, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_lalandia/gbfs.json')
# arg (134, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_freiburg/gbfs.json')
# arg (141, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_df/gbfs.json')
# 35 'en'
# arg (36, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_kortrijk_leiedal/gbfs')
# arg (85, 'https://gbfs.hopr.city/api/gbfs/36/')
# arg (64, 'https://data.lime.bike/api/partners/v2/gbfs/calgary/gbfs.json')
# arg (1, 'https://nordelta.publicbikesystem.net/ube/gbfs/v1/')
# argarg (162, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dj/gbfs.json')
#  (169, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dl/gbfs.json')
# arg (71, 'https://mds-global-bmt.neuron-mobility.com/gbfs/2/')
# arg (22, 'https://mds-global-lst.neuron-mobility.com/gbfs/2/')
# arg (15, 'https://mds-global-bdb.neuron-mobility.com/gbfs/2/')
# arg (78, 'https://data.rollapi.com/v1/gbfs/calgary/gbfs.json')
# 134 ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# arg (135, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_kiel/gbfs.json')
# arg (198, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_frederikshavn/gbfs.json')
# arg (205, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_middelfart/gbfs.json')
# arg (51, 'https://riodejaneiro.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# 182 Expecting value: line 1 column 1 (char 0)
# arg (183, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ug/gbfs.json')
# arg (113, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tl/gbfs.json')
# arg (176, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_wo/gbfs.json')
# arg (100, 'https://data.lime.bike/api/partners/v2/gbfs/zug/gbfs.json')
# arg (127, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_vr/gbfs.json')
# argarg (155, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_sn/gbfs.json')
#  (58, 'https://tor.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (8, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_la/gbfs.json')
# arg (120, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_to/gbfs.json')
# 92 'en'
# arg (93, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_kreuzlingen/gbfs.json')
# arg (190, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_gh/gbfs.json')
# arg (44, 'https://gbfs.getapony.com/v1/brussels/en/gbfs.json')
# arg (149, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_mz/gbfs.json')
# arg (107, 'https://nicosia.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (65, 'https://data.lime.bike/api/partners/v2/gbfs/edmonton/gbfs.json')
# 36 'en'
# arg (37, 'https://gbfs.api.ridedott.com/public/v2/brussels/gbfs.json')
# arg (30, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ba/gbfs.json')
# arg (142, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_da/gbfs.json')
# arg (86, 'https://mds.bird.co/gbfs/v2/public/basel/gbfs.json')
# arg (136, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_munich/gbfs.json')
# arg (199, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_glostrup/gbfs.json')
# arg (206, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_odense/gbfs.json')
# arg (101, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ch/gbfs.json')
# argarg (170, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dq/gbfs.json')
#  (163, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dk/gbfs.json')
# arg (66, 'https://data.lime.bike/api/partners/v2/gbfs/kelowna/gbfs.json')
# arg (184, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ag/gbfs.json')
# arg (2, 'https://buenosaires.publicbikesystem.net/ube/gbfs/v1/')
# arg (177, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dc/gbfs.json')
# arg (114, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tz/gbfs.json')
# arg (128, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tv/gbfs.json')
# arg (156, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bn/gbfs.json')
# arg (45, 'https://gbfs.getapony.com/v1/liege/en/gbfs.json')
# arg (9, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ta/gbfs.json')
# arg (121, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tm/gbfs.json')
# arg (191, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_wd/gbfs.json')
# arg (150, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dg/gbfs.json')
# arg (59, 'https://mds.bird.co/gbfs/v2/public/calgary/gbfs.json')
# arg (23, 'https://mds-global-mel.neuron-mobility.com/gbfs/2/')
# arg (108, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_td/gbfs.json')
# arg (87, 'https://mds.bird.co/gbfs/v2/public/biel/gbfs.json')
# arg (16, 'https://mds-global-blt.neuron-mobility.com/gbfs/2/')
# arg (72, 'https://mds-global-yyc.neuron-mobility.com/gbfs/2/')
# arg (52, 'https://riviera.publicbikesystem.net/ube/gbfs/v1/')
# arg (137, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_regensburg/gbfs.json')
# arg (200, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_herning/gbfs.json')
# arg (31, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bz/gbfs.json')
# arg (207, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_roedvig/gbfs.json')
# arg (38, 'https://gbfs.api.ridedott.com/public/v2/charleroi/gbfs.json')
# arg (143, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_hg/gbfs.json')
# arg (67, 'https://data.lime.bike/api/partners/v2/gbfs/ottawa/gbfs.json')
# arg (102, 'https://www.share-birrer.ch/gbfs/gbfs.json')
# 170 Expecting value: line 1 column 1 (char 0)
# arg (171, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_do/gbfs.json')
# arg (164, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_lr/gbfs.json')
# arg (46, 'https://gbfs.getapony.com/v1/namur/en/gbfs.json')
# arg (60, 'https://mds.bird.co/gbfs/v2/public/edmonton/gbfs.json')
# arg (88, 'https://mds.bird.co/gbfs/v2/public/bulle/gbfs.json')
# arg (185, 'https://nitro.openvelo.org/aachen/tier/v2/gbfs.json')
# arg (178, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_rb/gbfs.json')
# arg (115, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tk/gbfs.json')
# arg (138, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ed/gbfs.json')
# arg (201, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_hillerod/gbfs')
# arg (129, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ac/gbfs.json')
# arg (10, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_si/gbfs.json')
# arg (157, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dd/gbfs.json')
# arg (122, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ty/gbfs.json')
# arg (39, 'https://gbfs.api.ridedott.com/public/v2/ghent/gbfs.json')
# arg (192, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_wk/gbfs.json')
# arg (151, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_mr/gbfs.json')
# arg (208, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_store_heddinge/gbfs.json')
# arg (68, 'https://mds.linkyour.city/gbfs/ca_red_deer/gbfs.json')
# arg (109, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_te/gbfs.json')
# arg (3, 'https://www.mibicitubici.gob.ar/opendata/gbfs.json')
# arg (32, 'https://mds.bird.co/gbfs/v2/public/antwerp/gbfs.json')
# arg (144, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_kg/gbfs.json')
# arg (47, 'https://gbfs.smartbike.com/antwerp/1.0/gbfs.json')
# arg (61, 'https://mds.bird.co/gbfs/v2/public/ottawa/gbfs.json')
# arg (89, 'https://mds.bird.co/gbfs/v2/public/uster/gbfs.json')
# arg (53, 'https://salvador.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (186, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ur/gbfs.json')
# arg (24, 'https://mds-global-per.neuron-mobility.com/gbfs/2/')
# arg (73, 'https://mds-global-kcw.neuron-mobility.com/gbfs/2/')
# arg (165, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_le/gbfs.json')
# arg (172, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_wn/gbfs.json')
# arg (17, 'https://mds-global-bne.neuron-mobility.com/gbfs/2/')
# arg (202, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_kiel/gbfs')
# arg (40, 'https://gbfs.api.ridedott.com/public/v2/liege/gbfs.json')
# arg (209, 'https://mds.linkyour.city/gbfs/es_alcala_de_henares/gbfs.json')
# arg (33, 'https://api.delijn.be/gbfs/gbfs.json')
# arg (103, 'https://www.sharedmobility.ch/gbfs.json')
# arg (139, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_eb/gbfs.json')
# arg (179, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dr/gbfs.json')
# arg (116, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tw/gbfs.json')
# argarg (130, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cb/gbfs.json')
#  (69, 'https://vancouver-gbfs.smoove.pro/gbfs/2/gbfs.json')
# arg (11, 'https://mds.linkyour.city/gbfs/at_vienna/gbfs.json')
# arg (158, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ef/gbfs.json')
# arg (123, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tg/gbfs.json')
# arg (193, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dw/gbfs.json')
# arg (90, 'https://mds.bird.co/gbfs/v2/public/winterthur/gbfs.json')
# arg (152, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dx/gbfs.json')
# arg (62, 'https://gbfs.velobixi.com/gbfs/gbfs.json')
# arg (110, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tf/gbfs.json')
# 3 'en'
# arg (4, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_al/gbfs.json')
# arg (41, 'https://gbfs.api.ridedott.com/public/v2/namur/gbfs.json')
# 202 ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# arg (210, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bs/gbfs.json')
# arg (145, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_fg/gbfs.json')
# arg (217, 'https://mds.bird.co/gbfs/v2/public/madrid/gbfs.json')
# arg (224, 'https://gbfs.api.ridedott.com/public/v2/malaga/gbfs.json')
# arg (187, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dv/gbfs.json')
# arg (166, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_li/gbfs.json')
# arg (173, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dt/gbfs.json')
# arg (48, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bg/gbfs.json')
# arg (54, 'https://saopaulo.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (12, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_vt/gbfs.json')
# arg (231, 'https://mds.linkyour.city/gbfs/es_villaviciosa_de_odon/gbfs.json')
# 130 Expecting value: line 1 column 1 (char 0)
# arg (131, 'https://mds.bird.co/gbfs/v2/public/ulm/gbfs.json')
# arg (238, 'https://valladolid.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (180, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ds/gbfs.json')
# arg (124, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cz/gbfs.json')
# arg (117, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tq/gbfs.json')
# arg (159, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_er/gbfs.json')
# arg (153, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_re/gbfs.json')
# arg (194, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_aalborg/gbfs.json')
# arg (25, 'https://mds-global-rok.neuron-mobility.com/gbfs/2/')
# argarg (74, 'https://mds-global-yql.neuron-mobility.com/gbfs/2/')
#  (18, 'https://mds-global-cbr.neuron-mobility.com/gbfs/2/')
# arg (111, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ts/gbfs.json')
# arg (5, 'https://mds.linkyour.city/gbfs/at_linz/gbfs.json')
# arg (104, 'https://santiagodc.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# 33 'en'
# arg (34, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_antwerp/gbfs.json')
# arg (218, 'https://mds.bird.co/gbfs/v2/public/zaragoza/gbfs.json')
# arg (225, 'https://gbfs.api.ridedott.com/public/v2/seville/gbfs.json')
# arg (211, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ey/gbfs.json')
# arg (146, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_sk/gbfs.json')
# arg (245, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_kotka/gbfs.json')
# arg (252, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_riihimaki/gbfs')
# arg (132, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bf/gbfs.json')
# arg (188, 'https://nitro.openvelo.org/aachen/velocity/v2/gbfs.json')
# arg (167, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_nm/gbfs.json')
# 173 Expecting value: line 1 column 1 (char 0)
# arg (174, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dn/gbfs.json')
# arg (259, 'https://mds.bird.co/gbfs/v2/public/dieppe/gbfs.json')
# arg (232, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ls/gbfs.json')
# arg (219, 'https://mds.linkyour.city/gbfs/es_canary_islands/gbfs.json')
# arg (13, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_wr/gbfs.json')
# arg (226, 'https://mds.linkyour.city/gbfs/es_el_puerto_de_santa_maria/gbfs.json')
# arg (239, 'https://mds.linkyour.city/gbfs/es_vejer_de_la_frontera/gbfs.json')
# arg (55, 'https://vilavelha.publicbikesystem.net/ube/gbfs/v1/')
# arg (195, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_aarhus/gbfs.json')
# arg (181, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dh/gbfs.json')
# arg (266, 'https://mds.bird.co/gbfs/v2/public/millau/gbfs.json')
# arg (6, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_na/gbfs.json')
# arg (118, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ti/gbfs.json')
# arg (160, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ff/gbfs.json')
# arg (125, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tx/gbfs.json')
# arg (273, 'https://clermontferrand.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (253, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_turku/gbfs.json')
# arg (212, 'https://acoruna.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (260, 'https://mds.bird.co/gbfs/v2/public/draguignan/gbfs.json')
# arg (280, 'https://gbfs.api.ridedott.com/public/v2/lyon/gbfs.json')
# arg (287, 'https://valence.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (294, 'https://gbfs.getapony.com/v1/bordeaux/en/gbfs.json')
# arg (26, 'https://mds-global-syd.neuron-mobility.com/gbfs/2/')
# arg (19, 'https://mds-global-drw.neuron-mobility.com/gbfs/2/')
# arg (75, 'https://mds-global-yow.neuron-mobility.com/gbfs/2/')
# arg (301, 'https://data.mobilites-m.fr/api/gbfs/tier_grenoble/gbfs')
# arg (267, 'https://mds.bird.co/gbfs/v2/public/montlucon/gbfs.json')
# argarg (220, 'https://sansebastian.publicbikesystem.net/ube/gbfs/v1/')
#  (308, 'https://vannes-gbfs.klervi.net/gbfs/gbfs.json')
# arg (315, 'https://transport.data.gouv.fr/gbfs/lyon/gbfs.json')
# arg (233, 'https://mds.linkyour.city/gbfs/es_madrid/gbfs.json')
# arg (227, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ex/gbfs.json')
# arg (322, 'https://gbfs.beryl.cc/v2_2/Hereford/gbfs.json')
# 55 HTTPSConnectionPool(host='vilavelha.publicbikesystem.net', port=443): Max retries exceeded with url: /ube/gbfs/v1/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x160acaed0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# arg (329, 'https://gbfs.beryl.cc/v2_2/Portsmouth/gbfs.json')
# arg (240, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_haemeenlinna/gbfs.json')
# arg (254, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_fo/gbfs.json')
# argarg (336, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_charlbury/gbfs.json')
#  (261, 'https://mds.bird.co/gbfs/v2/public/epron/gbfs.json')
# arg (343, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_northleach/gbfs.json')
# arg (350, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_worthing/gbfs.json')
# arg (357, 'https://eu-feeds.joyridecity.bike/api/v1/ginger/stafford/gbfs/1/')
# arg (364, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_gg/gbfs.json')
# arg (281, 'https://gbfs.api.ridedott.com/public/v2/marseille/gbfs.json')
# arg (246, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_kouvola/gbfs.json')
# arg (295, 'https://gbfs.getapony.com/v1/evry/en/gbfs.json')
# arg (268, 'https://mds.bird.co/gbfs/v2/public/ouistreham/gbfs.json')
# arg (274, 'https://transport.data.gouv.fr/gbfs/rouen/gbfs.json')
# arg (241, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_hamina/gbfs.json')
# arg (213, 'https://gbfs.bici.madrid/gbfs.json')
# arg (262, 'https://mds.bird.co/gbfs/v2/public/herouvillesaintclair/gbfs.json')
# arg (221, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_barcelona/gbfs.json')
# arg (234, 'https://mds.linkyour.city/gbfs/es_malaga/gbfs.json')
# arg (288, 'https://data.lime.bike/api/partners/v2/gbfs/marseille/gbfs.json')
# arg (337, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_cheltenham_spa/gbfs.json')
# argarg (330, 'https://gbfs.beryl.cc/v2_2/Southampton/gbfs.json')
#  (323, 'https://gbfs.beryl.cc/v2_2/Hertsmere/gbfs.json')
# 246 ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# arg (247, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_lappeenranta/gbfs.json')
# arg (282, 'https://gbfs.api.ridedott.com/public/v2/ol-vallee/gbfs.json')
# arg (296, 'https://gbfs.getapony.com/v1/grenoble/en/gbfs.json')
# arg (228, 'https://mds.linkyour.city/gbfs/es_granada/gbfs.json')
# arg (255, 'https://transport.data.gouv.fr/gbfs/nantes/gbfs.json')
# arg (269, 'https://mds.bird.co/gbfs/v2/public/sarreguemines/gbfs.json')
# 301 'data'
# arg (302, 'https://transport.data.gouv.fr/gbfs/vcub/gbfs.json')
# arg (27, 'https://mds-global-tsv.neuron-mobility.com/gbfs/2/')
# 34 'en'
# arg (371, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ig/gbfs.json')
# arg (76, 'https://mds-global-yqf.neuron-mobility.com/gbfs/2/')
# arg (344, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_oxford/gbfs.json')
# arg (20, 'https://mds-global-fkt.neuron-mobility.com/gbfs/2/')
# arg (309, 'https://transport.data.gouv.fr/gbfs/besancon/gbfs.json')
# arg (365, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ub/gbfs.json')
# 315 'en'
# arg (316, 'https://api.gbfs.v1.ecovelo.mobi/gbfs/velyceo')
# arg (242, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_hyvinkaa/gbfs')
# arg (263, 'https://mds.bird.co/gbfs/v2/public/larochesuryon/gbfs.json')
# arg (222, 'https://gbfs.api.ridedott.com/public/v2/estepona/gbfs.json')
# arg (289, 'https://data.lime.bike/api/partners/v2/gbfs/paris/gbfs.json')
# 274 'en'
# arg (275, 'https://gbfs.urbansharing.com/cyclolib.fr/gbfs.json')
# arg (331, 'https://gbfs.beryl.cc/v2_2/Watford/gbfs.json')
# arg (324, 'https://gbfs.beryl.cc/v2_2/Isle_of_Wight/gbfs.json')
# arg (283, 'https://gbfs.api.ridedott.com/public/v2/paris/gbfs.json')
# arg (338, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_cirencester/gbfs.json')
# arg (297, 'https://gbfs.getapony.com/v1/lorient/en/gbfs.json')
# arg (94, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_le_locle/gbfs')
# arg (270, 'https://mds.bird.co/gbfs/v2/public/vichy/gbfs.json')
# arg (235, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_sl/gbfs.json')
# arg (358, 'https://gbfs.urbansharing.com/edinburghcyclehire.com/gbfs.json')
# arg (229, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ei/gbfs.json')
# 344 ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# arg (345, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_plymouth/gbfs.json')
# arg (264, 'https://mds.bird.co/gbfs/v2/public/laval/gbfs.json')
# arg (243, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_iisalmi/gbfs.json')
# 255 'en'
# arg (256, 'https://mds.bird.co/gbfs/v2/public/bordeaux/gbfs.json')
# 302 'en'
# arg (303, 'https://transport.data.gouv.fr/gbfs/amiens/gbfs.json')
# arg (223, 'https://gbfs.api.ridedott.com/public/v2/madrid/gbfs.json')
# arg (214, 'https://barcelona-sp.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (290, 'https://mds.linkyour.city/gbfs/fr_cagnessurmer/gbfs.json')
# argarg (332, 'https://gbfs.beryl.cc/v2_2/West_Midlands/gbfs.json')
#  (372, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_kc/gbfs.json')
# 309 'en'
# arg (310, 'https://transport.data.gouv.fr/gbfs/mulhouse/gbfs.json')
# arg (366, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ku/gbfs.json')
# arg (325, 'https://gbfs.beryl.cc/v2_2/London/gbfs.json')
# arg (339, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_henley_on_thames/gbfs.json')
# arg (284, 'https://gbfs.api.ridedott.com/public/v2/tignes/gbfs.json')
# arg (298, 'https://gbfs.getapony.com/v1/olivet/en/gbfs.json')
# arg (271, 'https://mds.linkyour.city/gbfs/fr_bordeaux/gbfs.json')
# argarg (378, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_gt/gbfs.json')
#  (359, 'https://mds.linkyour.city/gbfs/gb_derby/gbfs.json')
# 316 'en'
# arg (317, 'https://transport.data.gouv.fr/gbfs/vlille/gbfs.json')
# 275 'en'
# arg (276, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_brest/gbfs.json')
# arg (248, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_maentsaelae/gbfs.json')
# arg (385, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_hr/gbfs.json')
# arg (265, 'https://mds.bird.co/gbfs/v2/public/marseille/gbfs.json')
# arg (392, 'https://gbfs.api.ridedott.com/public/v2/tel-aviv/gbfs.json')
# argarg (399, 'https://gbfs.api.ridedott.com/public/v2/catania/gbfs.json')
#  (257, 'https://mds.bird.co/gbfs/v2/public/castres/gbfs.json')
# arg (406, 'https://gbfs.api.ridedott.com/public/v2/turin/gbfs.json')
# arg (95, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_neuchatel/gbfs.json')
# arg (236, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_el/gbfs.json')
# arg (333, 'https://gbfs.beryl.cc/v2_2/Wool/gbfs.json')
# arg (244, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_imatra/gbfs.json')
# arg (326, 'https://gbfs.beryl.cc/v2_2/London_Cargo_Bike/gbfs.json')
# arg (230, 'https://mds.linkyour.city/gbfs/es_rota/gbfs.json')
# arg (340, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_kingham/gbfs.json')
# arg (291, 'https://belfort-gbfs.klervi.net/gbfs/gbfs.json')
# arg (351, 'https://gbfs.api.ridedott.com/public/v2/bristol/gbfs.json')
# arg (285, 'https://transport.data.gouv.fr/gbfs/marseille/gbfs.json')
# 303 'en'
# arg (304, 'https://transport.data.gouv.fr/gbfs/strasbourg/gbfs.json')
# arg (299, 'https://gbfs.getapony.com/v1/paris/en/gbfs.json')
# 310 'en'
# arg (311, 'https://montpellier-fr-smoove.klervi.net/gbfs/gbfs.json')
# arg (373, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ma/gbfs.json')
# arg (367, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_uu/gbfs.json')
# arg (413, 'https://gbfs.helbiz.com/v2.2/cesena/gbfs.json')
# arg (393, 'https://data.lime.bike/api/partners/v2/gbfs/tel_aviv/gbfs.json')
# arg (272, 'https://transport.data.gouv.fr/gbfs/creteil/gbfs.json')
# arg (258, 'https://mds.bird.co/gbfs/v2/public/chalonsenchampagne/gbfs.json')
# arg (249, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_mikkeli/gbfs')
# arg (215, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ea/gbfs.json')
# arg (400, 'https://gbfs.api.ridedott.com/public/v2/ferrara/gbfs.json')
# arg (407, 'https://gbfs.api.ridedott.com/public/v2/varese/gbfs.json')
# arg (360, 'https://mds-global-ncl.neuron-mobility.com/gbfs/2/')
# arg (96, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_sion/gbfs.json')
# arg (334, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_eu/gbfs.json')
# 317 'en'
# arg (318, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bu/gbfs.json')
# arg (379, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cg/gbfs.json')
# 326 Expecting value: line 2 column 1 (char 1)
# arg (327, 'https://gbfs.beryl.cc/v2_2/Norwich/gbfs.json')
# arg (386, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_br/gbfs.json')
# arg (237, 'https://mds.linkyour.city/gbfs/es_tenerife/gbfs.json')
# arg (300, 'https://gbfs.getapony.com/v1/poitiers/en/gbfs.json')
# arg (420, 'https://gbfs.helbiz.com/v2.2/latina/gbfs.json')
# arg (277, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_valenciennes/gbfs.json')
# arg (394, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_reykjavik/gbfs.json')
# arg (427, 'https://gbfs.helbiz.com/v2.2/reggio/gbfs.json')
# arg (352, 'https://gbfs.api.ridedott.com/public/v2/london/gbfs.json')
# arg (401, 'https://gbfs.api.ridedott.com/public/v2/milan/gbfs.json')
# arg (408, 'https://gbfs.api.ridedott.com/public/v2/verona/gbfs.json')
# arg (434, 'https://mds.linkyour.city/gbfs/it_modena/gbfs.json')
# arg (250, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_porvoo/gbfs.json')
# arg (328, 'https://gbfs.beryl.cc/v2_2/Plymouth/gbfs.json')
# arg (374, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cm/gbfs.json')
# arg (341, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_miltonpark/gbfs')
# arg (414, 'https://gbfs.helbiz.com/v2.2/ferrara/gbfs.json')
# arg (346, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_stroud/gbfs.json')
# arg (312, 'https://avignon-gbfs.klervi.net/gbfs/gbfs.json')
# arg (368, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_su/gbfs.json')
# 272 'en'
# arg (441, 'https://mds.linkyour.city/gbfs/it_teramo/gbfs.json')
# arg (292, 'https://mds.linkyour.city/gbfs/fr_perpignan/gbfs.json')
# arg (216, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bo/gbfs.json')
# arg (421, 'https://gbfs.helbiz.com/v2.2/modena/gbfs.json')
# arg (335, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tb/gbfs.json')
# arg (448, 'https://monaco.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (380, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_vu/gbfs.json')
# arg (319, 'https://gbfs.beryl.cc/v2_2/BCP/gbfs.json')
# arg (395, 'https://mds.linkyour.city/gbfs/it_aprilia/gbfs.json')
# arg (428, 'https://gbfs.helbiz.com/v2.2/rho/gbfs.json')
# arg (455, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_den_haag/gbfs.json')
# arg (387, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_se/gbfs.json')
# argarg (402, 'https://gbfs.api.ridedott.com/public/v2/monza/gbfs.json')
#  (353, 'https://eu-feeds.joyridecity.bike/api/v1/ginger/chester/gbfs/1/')
# arg (462, 'https://gbfs.urbansharing.com/bergenbysykkel.no/gbfs.json')
# arg (415, 'https://gbfs.helbiz.com/v2.2/firenze/gbfs.json')
# arg (409, 'https://mds.linkyour.city/gbfs/it_giulianova/gbfs.json')
# arg (251, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_raasepori/gbfs')
# arg (347, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_tetbury/gbfs.json')
# arg (278, 'https://gbfs.api.ridedott.com/public/v2/bordeaux/gbfs.json')
# arg (361, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_uk/gbfs.json')
# arg (435, 'https://mds.linkyour.city/gbfs/it_moncalieri/gbfs.json')
# arg (305, 'https://velib-metropole-opendata.smoove.pro/opendata/Velib_Metropole/gbfs.json')
# arg (342, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_moreton_in_marsh/gbfs.json')
# arg (422, 'https://gbfs.helbiz.com/v2.2/napoli/gbfs.json')
# argarg (442, 'https://mds.linkyour.city/gbfs/it_turin/gbfs.json')
#  (375, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bc/gbfs.json')
# arg (293, 'https://gbfs.getapony.com/v1/angers/en/gbfs.json')
# arg (369, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_em/gbfs.json')
# arg (320, 'https://gbfs.beryl.cc/v2_2/Cornwall/gbfs.json')
# arg (429, 'https://gbfs.helbiz.com/v2.2/rome/gbfs.json')
# arg (403, 'https://gbfs.api.ridedott.com/public/v2/padua/gbfs.json')
# 455 'en'
# arg (456, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_dordrecht/gbfs.json')
# arg (416, 'https://gbfs.helbiz.com/v2.2/fiumicino/gbfs.json')
# arg (469, 'https://api.entur.io/mobility/v2/gbfs/boltlillestrom/gbfs')
# arg (476, 'https://api.entur.io/mobility/v2/gbfs/otto/gbfs')
# 462 'en'
# arg (463, 'https://api.entur.io/mobility/v2/gbfs/boltbergen/gbfs')
# arg (396, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ia/gbfs.json')
# arg (279, 'https://gbfs.api.ridedott.com/public/v2/grenoble/gbfs.json')
# arg (313, 'https://transport.data.gouv.fr/gbfs/nancy/gbfs.json')
# arg (381, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_zd/gbfs.json')
# arg (97, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_thun/gbfs.json')
# arg (483, 'https://api.entur.io/mobility/v2/gbfs/tierdrammen/gbfs')
# arg (410, 'https://gbfs.helbiz.com/v2.2/bari/gbfs.json')
# arg (449, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_mt/gbfs.json')
# arg (423, 'https://gbfs.helbiz.com/v2.2/palermo/gbfs.json')
# arg (388, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cv/gbfs.json')
# arg (354, 'https://eu-feeds.joyridecity.bike/api/v1/ginger/hartlepool/gbfs/1/')
# arg (490, 'https://api.entur.io/mobility/v2/gbfs/trondheimbysykkel/gbfs')
# arg (436, 'https://mds.linkyour.city/gbfs/it_nettuno/gbfs.json')
# arg (321, 'https://gbfs.beryl.cc/v2_2/Greater_Manchester/gbfs.json')
# arg (430, 'https://mds.linkyour.city/gbfs/it_isola_delle_femmine/gbfs.json')
# arg (404, 'https://gbfs.api.ridedott.com/public/v2/palermo/gbfs.json')
# arg (497, 'https://mds-global-dud.neuron-mobility.com/gbfs/2/')
# arg (362, 'https://mds.linkyour.city/gbfs/gb_nottingham/gbfs.json')
# arg (443, 'https://gbfs.urbansharing.com/bikeverona.it/gbfs.json')
# arg (417, 'https://gbfs.helbiz.com/v2.2/frosinone/gbfs.json')
# arg (286, 'https://eu.ftp.opendatasoft.com/star/gbfs/gbfs.json')
# argarg (376, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cs/gbfs.json')
#  (504, 'https://gbfs.api.ridedott.com/public/v2/sobieszewo-island/gbfs.json')
# 97arg (411, 'https://gbfs.helbiz.com/v2.2/catania/gbfs.json')
#  ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# arg (511, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_kw/gbfs.json')
# arg (424, 'https://gbfs.helbiz.com/v2.2/parma/gbfs.json')
# arg (370, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_gd/gbfs.json')
# arg (306, 'https://saint-etienne-gbfs.klervi.net/gbfs/gbfs.json')
# arg (397, 'https://mds.bird.co/gbfs/v2/public/rome/gbfs.json')
# 313 'en'
# arg (314, 'https://transport.data.gouv.fr/gbfs/toulouse/gbfs.json')
# arg (518, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ln/gbfs.json')
# arg (418, 'https://gbfs.helbiz.com/v2.2/genova/gbfs.json')
# arg (382, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_sg/gbfs.json')
# arg (405, 'https://gbfs.api.ridedott.com/public/v2/rome/gbfs.json')
# arg (355, 'https://eu-feeds.joyridecity.bike/api/v1/ginger/middlesbrough/gbfs/1/')
# 449 Expecting value: line 1 column 1 (char 0)
# arg (450, 'https://gbfs.mex.lyftbikes.com/gbfs/gbfs.json')
# 388 Expecting value: line 1 column 1 (char 0)
# arg (389, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_budapest/gbfs.json')
# 443 'en'
# arg (444, 'https://api-public.odpt.org/api/v4/gbfs/docomo-cycle-tokyo/gbfs.json')
# arg (437, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ib/gbfs.json')
# arg (431, 'https://data.lime.bike/api/partners/v2/gbfs/rome/gbfs.json')
# arg (363, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_uc/gbfs.json')
# argarg (412, 'https://gbfs.helbiz.com/v2.2/cervia/gbfs.json')
#  (425, 'https://gbfs.helbiz.com/v2.2/pescara/gbfs.json')
# arg (505, 'https://gbfs.api.ridedott.com/public/v2/tczew/gbfs.json')
# 286 'en'
# arg (525, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ep/gbfs.json')
# 490 'data'
# arg (491, 'https://api.entur.io/mobility/v2/gbfs/voi/gbfs')
# 483 'data'
# arg (484, 'https://api.entur.io/mobility/v2/gbfs/tierlillestrom/gbfs')
# arg (470, 'https://api.entur.io/mobility/v2/gbfs/boltoslo/gbfs')
# 476 'en'
# arg (477, 'https://api.entur.io/mobility/v2/gbfs/oslobysykkel/gbfs')
# arg (464, 'https://api.entur.io/mobility/v2/gbfs/boltdrammen/gbfs')
# arg (398, 'https://gbfs.api.ridedott.com/public/v2/alghero/gbfs.json')
# arg (377, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_sb/gbfs.json')
# arg (419, 'https://gbfs.helbiz.com/v2.2/h-farm/gbfs.json')
# arg (532, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_rq/gbfs.json')
# arg (512, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_kr/gbfs.json')
# arg (390, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bh/gbfs.json')
# arg (539, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_vw/gbfs.json')
# arg (348, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_the_cotswold_water_park/gbfs.json')
# arg (432, 'https://mds.linkyour.city/gbfs/it_mazara_del_vallo/gbfs.json')
# arg (498, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_nz/gbfs.json')
# 314 'en'
# arg (546, 'https://mds.linkyour.city/gbfs/pt_cascais/gbfs.json')
# arg (553, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_rt/gbfs.json')
# arg (426, 'https://gbfs.helbiz.com/v2.2/pisa/gbfs.json')
# 518 Expecting value: line 1 column 1 (char 0)
# arg (519, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pq/gbfs.json')
# arg (307, 'https://transport.data.gouv.fr/gbfs/cergy-pontoise/gbfs.json')
# arg (506, 'https://gbfs.api.ridedott.com/public/v2/tricity/gbfs.json')
# arg (451, 'https://guadalajara-mx.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (383, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ol/gbfs.json')
# arg (356, 'https://eu-feeds.joyridecity.bike/api/v1/ginger/milton-keynes/gbfs/1/')
# arg (438, 'https://mds.linkyour.city/gbfs/it_palermo/gbfs.json')
# arg (560, 'https://mds.linkyour.city/gbfs/se_stockholm/gbfs.json')
# 456 'en'
# arg (457, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_rt/gbfs.json')
# arg (567, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cl/gbfs.json')
# arg (574, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_uv/gbfs.json')
# 484525 Expecting value: line 1 column 1 (char 0)
# arg (526, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pu/gbfs.json')
#  'data'
# arg (485, 'https://api.entur.io/mobility/v2/gbfs/tierlorenskog/gbfs')
# arg (492, 'https://api.entur.io/mobility/v2/gbfs/zvipptrondheim/gbfs')
# 470 'data'
# arg (471, 'https://api.entur.io/mobility/v2/gbfs/brakarbysykkel/gbfs')
# 477 'data'
# arg (478, 'https://api.entur.io/mobility/v2/gbfs/rydebergen/gbfs')
# arg (465, 'https://api.entur.io/mobility/v2/gbfs/boltfredrikstad/gbfs')
# arg (349, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_whichford/gbfs.json')
# 444 'en'
# arg (445, 'https://api-public.odpt.org/api/v4/gbfs/hellocycling/gbfs.json')
# arg (581, 'https://chat.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (588, 'https://mds.bird.co/gbfs/v2/public/baltimore/gbfs.json')
# arg (433, 'https://gbfs.urbansharing.com/bikemi.com/gbfs.json')
# arg (533, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_sc/gbfs.json')
# arg (513, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_mk/gbfs.json')
# argarg (540, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pl/gbfs.json')
#  (391, 'https://mds.bird.co/gbfs/v2/public/tel-aviv/gbfs.json')
# arg (547, 'https://mds.linkyour.city/gbfs/pt_faro/gbfs.json')
# arg (507, 'https://gbfs.api.ridedott.com/public/v2/warsaw/gbfs.json')
# 457 'en'
# arg (458, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_ut/gbfs.json')
# 498 Expecting value: line 1 column 1 (char 0)
# arg (499, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bp/gbfs.json')
# 307 'en'
# arg (595, 'https://mds.bird.co/gbfs/v2/public/durham/gbfs.json')
# 519 Expecting value: line 1 column 1 (char 0)
# arg (520, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_km/gbfs.json')
# arg (554, 'https://santana.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (561, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_zg/gbfs.json')
# arg (439, 'https://mds.linkyour.city/gbfs/it_pomezia/gbfs.json')
# arg (384, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cj/gbfs.json')
# arg (602, 'https://mds.bird.co/gbfs/v2/public/new-york/gbfs.json')
# arg (589, 'https://gbfs.bcycle.com/bcycle_boulder/gbfs.json')
# arg (609, 'https://gbsf.movatic.co/en/1.1/576347857979998215')
# arg (582, 'https://gbfs.bcycle.com/bcycle_bikelnk/gbfs.json')
# arg (452, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_yp/gbfs.json')
# arg (568, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cf/gbfs.json')
# arg (575, 'https://gbfs.hopr.city/api/gbfs/17/')
# arg (616, 'https://gbfs.bcycle.com/bcycle_clarksville/gbfs.json')
# arg (486, 'https://api.entur.io/mobility/v2/gbfs/tieroslo/gbfs')
# arg (527, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pb/gbfs.json')
# 492 'data'
# arg (493, 'https://data.rideflamingo.com/gbfs/palmerston-north/gbfs.json')
# 471 'data'
# arg (472, 'https://api.entur.io/mobility/v2/gbfs/hertzbildeling/gbfs')
# 478 'en'
# arg (479, 'https://api.entur.io/mobility/v2/gbfs/rydestavanger/gbfs')
# 465 'data'
# arg (466, 'https://api.entur.io/mobility/v2/gbfs/boltgjovik/gbfs')
# arg (508, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_gp/gbfs.json')
# 458 'en'
# arg (459, 'https://gbfs.goabout.com/2/gbfs.json')
# 445 'en'
# arg (446, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_li/gbfs.json')
# arg (596, 'https://mds.bird.co/gbfs/v2/public/fairfax/gbfs.json')
# arg (548, 'https://mds.linkyour.city/gbfs/pt_lisbon/gbfs.json')
# 433 'en'
# arg (623, 'https://mds.linkyour.city/gbfs/us_oh_columbus/gbfs.json')
# arg (603, 'https://mds.bird.co/gbfs/v2/public/portland/gbfs.json')
# 513 Expecting value: line 1 column 1 (char 0)
# arg (514, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pa/gbfs.json')
# 533 Expecting value: line 1 column 1 (char 0)
# arg (534, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pr/gbfs.json')
# arg (541, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pm/gbfs.json')
# arg (500, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pd/gbfs.json')
# arg (440, 'https://mds.linkyour.city/gbfs/it_rome/gbfs.json')
# arg (555, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_aengelholm/gbfs.json')
# arg (521, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pf/gbfs.json')
# arg (562, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ce/gbfs.json')
# arg (610, 'https://gbfs.bcycle.com/bcycle_broward/gbfs.json')
# arg (630, 'https://mds.linkyour.city/gbfs/us_va_fairfax/gbfs.json')
# arg (597, 'https://mds.bird.co/gbfs/v2/public/indianapolis/gbfs.json')
# arg (576, 'https://mds.linkyour.city/gbfs/us_nj_asbury_park/gbfs.json')
# arg (583, 'https://kona.publicbikesystem.net/ube/gbfs/v1/')
# arg (617, 'https://gbfs.bcycle.com/bcycle_clemson/gbfs.json')
# arg (590, 'https://mds.bird.co/gbfs/v2/public/chicago/gbfs.json')
# arg (604, 'https://mds.bird.co/gbfs/v2/public/san-francisco/gbfs.json')
# arg (569, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_as/gbfs.json')
# arg (453, 'https://www.cykl.nl/gbfs/gbfs.json')
# 486 'data'
# arg (487, 'https://api.entur.io/mobility/v2/gbfs/tierski/gbfs')
# 527 Expecting value: line 1 column 1 (char 0)
# arg (528, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_or/gbfs.json')
# 472 'en'
# arg (473, 'https://api.entur.io/mobility/v2/gbfs/kolumbusbysykkel/gbfs')
# 479 'en'
# arg (480, 'https://api.entur.io/mobility/v2/gbfs/rydetrondheim/gbfs')
# 466 'data'
# arg (467, 'https://api.entur.io/mobility/v2/gbfs/bolthamar/gbfs')
# arg (509, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pv/gbfs.json')
# 459 'en'
# arg (460, 'http://gbfs.openov.nl/ovfiets/gbfs.json')
# 446 'en'
# arg (447, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_lv/gbfs.json')
# arg (549, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_rd/gbfs.json')
# arg (624, 'https://gbfs.bcycle.com/bcycle_desmoines/gbfs.json')
# arg (494, 'https://data.rideflamingo.com/gbfs/waimakariri/gbfs.json')
# arg (556, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_baastad/gbfs.json')
# arg (611, 'https://gbfs.bcycle.com/bcycle_bublr/gbfs.json')
# arg (598, 'https://mds.bird.co/gbfs/v2/public/kansas-city/gbfs.json')
# arg (542, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_zy/gbfs.json')
# 514 Expecting value: line 1 column 1 (char 0)
# arg (515, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pn/gbfs.json')
# arg (535, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ap/gbfs.json')
# arg (637, 'https://gbfs.helbiz.com/v2.2/arlington/gbfs.json')
# arg (618, 'https://mds.linkyour.city/gbfs/us_oh_cleveland/gbfs.json')
# arg (501, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_jp/gbfs.json')
# arg (591, 'https://mds.bird.co/gbfs/v2/public/cleveland/gbfs.json')
# arg (631, 'https://gbfs.bcycle.com/bcycle_fortworth/gbfs.json')
# arg (605, 'https://mds.bird.co/gbfs/v2/public/st-louis/gbfs.json')
# arg (522, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_os/gbfs.json')
# arg (563, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cd/gbfs.json')
# argarg (577, 'https://mds.linkyour.city/gbfs/us_tx_austin/gbfs.json')
#  (625, 'https://mds.linkyour.city/gbfs/us_mi_detroit/gbfs.json')
# 460 Expecting value: line 1 column 1 (char 0)
# arg (461, 'https://api.entur.io/mobility/v2/gbfs/bergenbysykkel/gbfs')
# arg (495, 'https://data.rideflamingo.com/gbfs/wellington/gbfs.json')
# arg (612, 'https://gbfs.capitalbikeshare.com/gbfs/gbfs.json')
# arg (557, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_malmoe/gbfs.json')
# arg (454, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_am/gbfs.json')
# arg (570, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ak/gbfs.json')
# 528 Expecting value: line 1 column 1 (char 0)
# arg (529, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_rm/gbfs.json')
# arg (599, 'https://mds.bird.co/gbfs/v2/public/los-angeles/gbfs.json')
# 487 'data'
# arg (488, 'https://api.entur.io/mobility/v2/gbfs/tierstavanger/gbfs')
# 473 'en'
# arg (474, 'https://api.entur.io/mobility/v2/gbfs/lillestrombysykkel/gbfs')
# arg (510, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pk/gbfs.json')
# 480 'data'
# arg (481, 'https://api.entur.io/mobility/v2/gbfs/tierasker/gbfs')
# 467 'data'
# arg (468, 'https://api.entur.io/mobility/v2/gbfs/boltlillehammer/gbfs')
# arg (584, 'https://gbfs.biketownpdx.com/gbfs/gbfs.json')
# arg (638, 'https://gbfs.helbiz.com/v2.2/durham/gbfs.json')
# arg (550, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_nw/gbfs.json')
# arg (592, 'https://mds.bird.co/gbfs/v2/public/columbus/gbfs.json')
# arg (644, 'https://gbfs.helbiz.com/v2.2/orlando/gbfs.json')
# arg (632, 'https://gbfs.bcycle.com/bcycle_greenbikeslc/gbfs.json')
# arg (606, 'https://mds.bird.co/gbfs/v2/public/tempe/gbfs.json')
# arg (619, 'https://portal.clevrmobility.com/api/gbfs/oakland/en/discovery/')
# arg (543, 'https://mds.bird.co/gbfs/v2/public/braga/gbfs.json')
# arg (516, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ps/gbfs.json')
# arg (536, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pg/gbfs.json')
# arg (502, 'https://gbfs.api.ridedott.com/public/v2/malbork/gbfs.json')
# argarg (626, 'https://gbfs.divvybikes.com/gbfs/gbfs.json')
#  (578, 'https://gbfs.bcycle.com/bcycle_austin/gbfs.json')
# 522 Expecting value: line 1 column 1 (char 0)
# arg (523, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pi/gbfs.json')
# arg (600, 'https://mds.bird.co/gbfs/v2/public/louisville/gbfs.json')
# arg (564, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cn/gbfs.json')
# arg (558, 'https://stables.donkey.bike/api/public/gbfs/2/donkey_ystad/gbfs.json')
# arg (496, 'https://mds-global-chc.neuron-mobility.com/gbfs/2/')
# arg (593, 'https://mds.bird.co/gbfs/v2/public/culver-city/gbfs.json')
# 461 'en'
# arg (651, 'https://gbfs.hopr.city/api/gbfs/27/')
# arg (639, 'https://gbfs.helbiz.com/v2.2/flint/gbfs.json')
# arg (633, 'https://gbfs.bcycle.com/bcycle_greenville/gbfs.json')
# arg (645, 'https://gbfs.helbiz.com/v2.2/richmond/gbfs.json')
# arg (607, 'https://mds.bird.co/gbfs/v2/public/washington-dc/gbfs.json')
# argarg (544, 'https://mds.bird.co/gbfs/v2/public/cascais/gbfs.json')
#  (571, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tr/gbfs.json')
# 529 Expecting value: line 1 column 1 (char 0)
# arg (530, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_po/gbfs.json')
# arg (613, 'https://gbfs.bcycle.com/bcycle_charlotte/gbfs.json')
# 454 'en'
# arg (658, 'https://gbfs.bcycle.com/bcycle_indego/gbfs.json')
# arg510 Expecting value: line 1 column 1 (char 0)
# arg (665, 'https://data.lime.bike/api/partners/v2/gbfs/cleveland/gbfs.json')
#  (503, 'https://gbfs.api.ridedott.com/public/v2/poznan/gbfs.json')
# arg (551, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_rs/gbfs.json')
# arg (579, 'https://gbfs.bcycle.com/bcycle_aventura/gbfs.json')
# arg (601, 'https://mds.bird.co/gbfs/v2/public/miami/gbfs.json')
# arg (620, 'https://coast.socialbicycles.com/opendata/gbfs.json')
# arg (585, 'https://hon.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# 468 'data'
# arg (672, 'https://data.lime.bike/api/partners/v2/gbfs/portland/gbfs.json')
# arg (594, 'https://mds.bird.co/gbfs/v2/public/detroit/gbfs.json')
# arg (482, 'https://api.entur.io/mobility/v2/gbfs/tierbaerum/gbfs')
# 474 'data'
# arg (475, 'https://api.entur.io/mobility/v2/gbfs/moveaboutno/gbfs')
# arg (559, 'https://gbfs.api.ridedott.com/public/v2/stockholm/gbfs.json')
# arg (489, 'https://api.entur.io/mobility/v2/gbfs/tiertrondheim/gbfs')
# 536 Expecting value: line 1 column 1 (char 0)
# arg (537, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tn/gbfs.json')
# arg (517, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_oa/gbfs.json')
# arg (634, 'https://mds.linkyour.city/gbfs/us_ct_hartford/gbfs.json')
# arg (640, 'https://gbfs.helbiz.com/v2.2/jacksonville/gbfs.json')
# arg (646, 'https://gbfs.helbiz.com/v2.2/sacramento/gbfs.json')
# arg (608, 'https://gbfs.bluebikes.com/gbfs/gbfs.json')
# arg (545, 'https://mds.bird.co/gbfs/v2/public/lisbon/gbfs.json')
# arg (614, 'https://gbfs.bcycle.com/bcycle_cincyredbike/gbfs.json')
# arg (524, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dp/gbfs.json')
# arg (565, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ck/gbfs.json')
# arg (679, 'https://mds.linkyour.city/gbfs/us_va_arlington/gbfs.json')
# arg (627, 'https://gbfs.bcycle.com/bcycle_elpaso/gbfs.json')
# argarg (580, 'https://gbfs.baywheels.com/gbfs/gbfs.json')
#  (659, 'https://gbfs.bcycle.com/bcycle_pacersbikeshare/gbfs.json')
# arg (686, 'https://mds.linkyour.city/gbfs/us_ca_san_jose/gbfs.json')
# arg (666, 'https://data.lime.bike/api/partners/v2/gbfs/colorado_springs/gbfs.json')
# arg (652, 'https://gbfs.hopr.city/api/gbfs/16/')
# arg (673, 'https://data.lime.bike/api/partners/v2/gbfs/providence/gbfs.json')
# arg (693, 'https://s3.amazonaws.com/lyft-lastmile-production-iad/lbs/lax/gbfs.json')
# argarg (647, 'https://gbfs.helbiz.com/v2.2/santabarbara/gbfs.json')
#  (572, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_nk/gbfs.json')
# arg (641, 'https://gbfs.helbiz.com/v2.2/miami/gbfs.json')
# arg (531, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pw/gbfs.json')
# arg (552, 'https://sibiu.publicbikesystem.net/operation/customer/gbfs/v2/gbfs.json')
# arg (621, 'https://gbfs.hopr.city/api/gbfs/26/')
# arg (700, 'https://gbfs.bcycle.com/bcycle_lametro/gbfs.json')
# arg (707, 'https://mds.linkyour.city/gbfs/us_ut_provo/gbfs.json')
# arg (615, 'https://gbfs.citibikenyc.com/gbfs/gbfs.json')
# argarg (660, 'https://gbfs.bcycle.com/bcycle_jacksoncounty/gbfs.json')
#  (635, 'https://gbfs.bcycle.com/bcycle_heartland/gbfs.json')
# arg (628, 'https://gbfs.bcycle.com/bcycle_encinitas/gbfs.json')
# arg (714, 'https://gbfs.gorevel.com/gbfs/v2/newyork/en/gbfs.json')
# 475 'data'
# arg (721, 'https://mds.linkyour.city/gbfs/us_ca_san_diego/gbfs.json')
# arg (728, 'https://gbfs.spin.pm/api/gbfs/v2_3/alexandria/gbfs')
# arg (538, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pt/gbfs.json')
# arg (735, 'https://gbfs.spin.pm/api/gbfs/v2_3/brookline/gbfs')
# arg (742, 'https://gbfs.spin.pm/api/gbfs/v2_3/denver/gbfs')
# arg (586, 'https://mds.bird.co/gbfs/v2/public/alexandria/gbfs.json')
# arg (667, 'https://data.lime.bike/api/partners/v2/gbfs/detroit/gbfs.json')
# arg (749, 'https://gbfs.spin.pm/api/gbfs/v2_3/gainesville/gbfs')
# arg (687, 'https://mds.linkyour.city/gbfs/us_wa_seattle/gbfs.json')
# arg (680, 'https://mds.linkyour.city/gbfs/us_md_baltimore/gbfs.json')
# arg (756, 'https://gbfs.spin.pm/api/gbfs/v2_3/kansas_city/gbfs')
# arg (642, 'https://gbfs.helbiz.com/v2.2/miamilakes/gbfs.json')
# arg (674, 'https://data.lime.bike/api/partners/v2/gbfs/san_francisco/gbfs.json')
# arg (648, 'https://gbfs.helbiz.com/v2.2/washington/gbfs.json')
# arg (701, 'https://detroit-us.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# 565 Expecting value: line 1 column 1 (char 0)
# arg (566, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cc/gbfs.json')
# arg (763, 'https://gbfs.spin.pm/api/gbfs/v2_3/memphis/gbfs')
# arg (629, 'https://gbfs.bcycle.com/bcycle_memphis/gbfs.json')
# arg (636, 'https://gbfs.helbiz.com/v2.2/alexandria/gbfs.json')
# arg (661, 'https://mds.linkyour.city/gbfs/us_fl_jacksonville/gbfs.json')
# arg (653, 'https://gbfs.hopr.city/api/gbfs/21/')
# arg (770, 'https://gbfs.spin.pm/api/gbfs/v2_3/nicholls_state/gbfs')
# arg (622, 'https://gbfs.cogobikeshare.com/gbfs/gbfs.json')
# arg (708, 'https://gbfs.hopr.city/api/gbfs/33/')
# arg (777, 'https://gbfs.spin.pm/api/gbfs/v2_3/phoenix/gbfs')
# arg (668, 'https://data.lime.bike/api/partners/v2/gbfs/grand_rapids/gbfs.json')
# arg (587, 'https://mds.bird.co/gbfs/v2/public/arlingtonco/gbfs.json')
# arg (573, 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_nu/gbfs.json')
# arg (784, 'https://gbfs.spin.pm/api/gbfs/v2_3/salem/gbfs')
# arg (694, 'https://s3.amazonaws.com/lyft-lastmile-production-iad/lbs/mia/gbfs.json')
# arg (722, 'https://gbfs.bcycle.com/bcycle_santabarbara/gbfs.json')
# arg (715, 'https://gbfs.gorevel.com/gbfs/v2/oakland/en/gbfs.json')
# arg (643, 'https://gbfs.helbiz.com/v2.2/oklahoma/gbfs.json')
# arg (675, 'https://data.lime.bike/api/partners/v2/gbfs/san_jose/gbfs.json')
# argarg (649, 'https://gbfs.helbiz.com/v2.2/waterloo/gbfs.json')
#  (757, 'https://gbfs.spin.pm/api/gbfs/v2_3/knoxville/gbfs')
# arg (736, 'https://gbfs.spin.pm/api/gbfs/v2_3/charlotte/gbfs')
# arg (729, 'https://gbfs.spin.pm/api/gbfs/v2_3/ann_arbor/gbfs')
# arg (791, 'https://gbfs.spin.pm/api/gbfs/v2_3/seattle/gbfs')
# arg (743, 'https://gbfs.spin.pm/api/gbfs/v2_3/detroit/gbfs')
# arg (750, 'https://gbfs.spin.pm/api/gbfs/v2_3/garden_city/gbfs')
# arg (764, 'https://gbfs.spin.pm/api/gbfs/v2_3/mesa/gbfs')
# arg (798, 'https://gbfs.spin.pm/api/gbfs/v2_3/tempe/gbfs')
# arg (681, 'https://mds.linkyour.city/gbfs/us_il_chicago/gbfs.json')
# arg (688, 'https://gbfs.hopr.city/api/gbfs/10')
# arg (805, 'https://gbfs.spin.pm/api/gbfs/v2_3/washington_dc/gbfs')
# arg (771, 'https://gbfs.spin.pm/api/gbfs/v2_3/nmsu/gbfs')
# arg (778, 'https://gbfs.spin.pm/api/gbfs/v2_3/pittsburgh/gbfs')
# arg (785, 'https://gbfs.spin.pm/api/gbfs/v2_3/salt_lake_city/gbfs')
# arg (669, 'https://data.lime.bike/api/partners/v2/gbfs/louisville/gbfs.json')
# arg (812, 'https://aspen.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (819, 'https://seattle-gbfs.getwheelsapp.com/gbfs.json')
# argarg (702, 'https://gbfs.bcycle.com/bcycle_nashville/gbfs.json')
#  (662, 'https://mds.linkyour.city/gbfs/us_tn_knoxville/gbfs.json')
# arg (723, 'https://sbu.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (716, 'https://gbfs.gorevel.com/gbfs/v2/sanfrancisco/en/gbfs.json')
# arg (654, 'https://gbfs.hopr.city/api/gbfs/11/')
# arg (676, 'https://data.lime.bike/api/partners/v2/gbfs/seattle/gbfs.json')
# arg (737, 'https://gbfs.spin.pm/api/gbfs/v2_3/chicago_territory/gbfs')
# argarg (730, 'https://gbfs.spin.pm/api/gbfs/v2_3/asbury_park/gbfs')
#  (758, 'https://gbfs.spin.pm/api/gbfs/v2_3/lexington/gbfs')
# arg (695, 'https://s3.amazonaws.com/lyft-lastmile-production-iad/lbs/msp/gbfs.json')
# arg (744, 'https://gbfs.spin.pm/api/gbfs/v2_3/duke/gbfs')
# arg (792, 'https://gbfs.spin.pm/api/gbfs/v2_3/south_miami/gbfs')
# arg (650, 'https://gbfs.hopr.city/api/gbfs/20/')
# arg (709, 'https://razorapi.net/api/v1/gbfs/Tempe/gbfs.json')
# arg (751, 'https://gbfs.spin.pm/api/gbfs/v2_3/grand_rapids/gbfs')
# arg (765, 'https://gbfs.spin.pm/api/gbfs/v2_3/miami/gbfs')
# arg (799, 'https://gbfs.spin.pm/api/gbfs/v2_3/towson/gbfs')
# arg (806, 'https://gbfs.spin.pm/api/gbfs/v2_3/white_center/gbfs')
# arg (772, 'https://gbfs.spin.pm/api/gbfs/v2_3/oakland_university/gbfs')
# arg (779, 'https://gbfs.spin.pm/api/gbfs/v2_3/portland/gbfs')
# arg (786, 'https://gbfs.spin.pm/api/gbfs/v2_3/san_antonio/gbfs')
# arg (670, 'https://data.lime.bike/api/partners/v2/gbfs/new_york/gbfs.json')
# arg (682, 'https://mds.linkyour.city/gbfs/us_tx_dallas/gbfs.json')
# arg (703, 'https://gbfs.niceridemn.com/gbfs/gbfs.json')
# arg (717, 'https://gbfs.gorevel.com/gbfs/v2/washingtondc/en/gbfs.json')
# arg (689, 'https://lou.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (677, 'https://data.lime.bike/api/partners/v2/gbfs/washington_dc/gbfs.json')
# arg (738, 'https://gbfs.spin.pm/api/gbfs/v2_3/cleveland/gbfs')
# arg (731, 'https://gbfs.spin.pm/api/gbfs/v2_3/atlanta/gbfs')
# arg (752, 'https://gbfs.spin.pm/api/gbfs/v2_3/greenville/gbfs')
# arg (793, 'https://gbfs.spin.pm/api/gbfs/v2_3/st_george/gbfs')
# arg (745, 'https://gbfs.spin.pm/api/gbfs/v2_3/durham/gbfs')
# arg (759, 'https://gbfs.spin.pm/api/gbfs/v2_3/lincoln/gbfs')
# arg (663, 'https://data.lime.bike/api/partners/v2/gbfs/arlington/gbfs.json')
# arg (655, 'https://gbfs.hopr.city/api/gbfs/32/')
# arg (800, 'https://gbfs.spin.pm/api/gbfs/v2_3/troy/gbfs')
# arg (724, 'https://gbfs.hopr.city/api/gbfs/25/')
# arg (773, 'https://gbfs.spin.pm/api/gbfs/v2_3/ohio_state/gbfs')
# arg (766, 'https://gbfs.spin.pm/api/gbfs/v2_3/michigan_state_university/gbfs')
# arg (807, 'https://gbfs.spin.pm/api/gbfs/v2_3/wichita/gbfs')
# arg (696, 'https://s3.amazonaws.com/lyft-lastmile-production-iad/lbs/san/gbfs.json')
# arg (780, 'https://gbfs.spin.pm/api/gbfs/v2_3/providence/gbfs')
# arg (813, 'https://austin-gbfs.getwheelsapp.com/gbfs.json')
# arg (710, 'https://razorapi.net/api/v1/gbfs/Washington%20DC/gbfs.json')
# arg (787, 'https://gbfs.spin.pm/api/gbfs/v2_3/san_diego/gbfs')
# arg (671, 'https://data.lime.bike/api/partners/v2/gbfs/oakland/gbfs.json')
# 78 HTTPSConnectionPool(host='data.rollapi.com', port=443): Max retries exceeded with url: /v1/gbfs/calgary/gbfs.json (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1002)')))
# arg (79, 'https://data.rollapi.com/v1/gbfs/kelowna/gbfs.json')
# arg (820, 'https://tallahassee-gbfs.getwheelsapp.com/gbfs.json')
# arg (678, 'https://mds.linkyour.city/gbfs/us_va_alexandria/gbfs.json')
# arg (718, 'https://gbfs.bcycle.com/bcycle_rtcbikeshare/gbfs.json')
# arg (794, 'https://gbfs.spin.pm/api/gbfs/v2_3/stillwater/gbfs')
# arg (739, 'https://gbfs.spin.pm/api/gbfs/v2_3/columbus/gbfs')
# arg (683, 'https://mds.linkyour.city/gbfs/us_ca_los_angeles/gbfs.json')
# arg (746, 'https://gbfs.spin.pm/api/gbfs/v2_3/fayetteville/gbfs')
# arg (753, 'https://gbfs.spin.pm/api/gbfs/v2_3/isla_vista/gbfs')
# arg (732, 'https://gbfs.spin.pm/api/gbfs/v2_3/austin/gbfs')
# arg (760, 'https://gbfs.spin.pm/api/gbfs/v2_3/long_beach/gbfs')
# arg (690, 'https://s3.amazonaws.com/lyft-lastmile-production-iad/lbs/dca/gbfs.json')
# arg (774, 'https://gbfs.spin.pm/api/gbfs/v2_3/omaha/gbfs')
# arg (808, 'https://gbfs.spin.pm/api/gbfs/v2_3/winston_salem/gbfs')
# arg (801, 'https://gbfs.spin.pm/api/gbfs/v2_3/uc_san_diego/gbfs')
# arg (664, 'https://data.lime.bike/api/partners/v2/gbfs/chicago/gbfs.json')
# arg (767, 'https://gbfs.spin.pm/api/gbfs/v2_3/minneapolis/gbfs')
# arg (781, 'https://gbfs.spin.pm/api/gbfs/v2_3/provo/gbfs')
# arg (711, 'https://reddybikeshare.socialbicycles.com/opendata/gbfs.json')
# arg (788, 'https://gbfs.spin.pm/api/gbfs/v2_3/san_francisco/gbfs')
# arg (704, 'https://gbfs.bcycle.com/bcycle_spokies/gbfs.json')
# arg (719, 'https://mds.linkyour.city/gbfs/us_ut_salt_lake_city/gbfs.json')
# arg (697, 'https://gbfs.bcycle.com/bcycle_madison/gbfs.json')
# arg (725, 'https://gbfs.bcycle.com/bcycle_spartanburg/gbfs.json')
# arg (754, 'https://gbfs.spin.pm/api/gbfs/v2_3/jacksonville/gbfs')
# arg (656, 'https://gbfs.hopr.city/api/gbfs/8/')
# arg (795, 'https://gbfs.spin.pm/api/gbfs/v2_3/st_louis/gbfs')
# arg (740, 'https://gbfs.spin.pm/api/gbfs/v2_3/coral_gables/gbfs')
# arg (747, 'https://gbfs.spin.pm/api/gbfs/v2_3/fort_collins/gbfs')
# arg (761, 'https://gbfs.spin.pm/api/gbfs/v2_3/los_angeles/gbfs')
# arg (733, 'https://gbfs.spin.pm/api/gbfs/v2_3/baltimore/gbfs.json')
# arg (775, 'https://gbfs.spin.pm/api/gbfs/v2_3/orem/gbfs')
# arg (802, 'https://gbfs.spin.pm/api/gbfs/v2_3/university_of_central_florida/gbfs')
# arg (809, 'https://gbfs.bcycle.com/bcycle_startbike/gbfs.json')
# arg (768, 'https://gbfs.spin.pm/api/gbfs/v2_3/montgomery_county/gbfs')
# arg (782, 'https://gbfs.spin.pm/api/gbfs/v2_3/purdue_university/gbfs')
# arg (684, 'https://mds.linkyour.city/gbfs/us_ks_manhattan/gbfs.json')
# arg (814, 'https://dfw-gbfs.getwheelsapp.com/gbfs.json')
# arg (789, 'https://gbfs.spin.pm/api/gbfs/v2_3/san_marcos/gbfs')
# arg (691, 'https://s3.amazonaws.com/lyft-lastmile-production-iad/lbs/chi/gbfs.json')
# arg (821, 'https://tempe-gbfs.getwheelsapp.com/gbfs.json')
# arg (698, 'https://gbfs.bcycle.com/bcycle_mcallen/gbfs.json')
# arg (705, 'https://peacehealthrides.com/opendata/gbfs.json')
# arg (726, 'https://gbfs.spin.pm/api/gbfs/v2_3/akron/gbfs')
# arg (755, 'https://gbfs.spin.pm/api/gbfs/v2_3/jefferson_city/gbfs')
# arg (796, 'https://gbfs.spin.pm/api/gbfs/v2_3/tallahassee/gbfs')
# arg (741, 'https://gbfs.spin.pm/api/gbfs/v2_3/dayton/gbfs')
# arg (748, 'https://gbfs.spin.pm/api/gbfs/v2_3/fort_pierce/gbfs')
# arg (712, 'https://relaybikeshare.socialbicycles.com/opendata/gbfs.json')
# arg (734, 'https://gbfs.spin.pm/api/gbfs/v2_3/boise/gbfs')
# arg (762, 'https://gbfs.spin.pm/api/gbfs/v2_3/louisville/gbfs')
# arg (776, 'https://gbfs.spin.pm/api/gbfs/v2_3/orlando/gbfs')
# 809 'data'
# arg (810, 'https://tucson.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (803, 'https://gbfs.spin.pm/api/gbfs/v2_3/university_of_kentucky/gbfs')
# arg (769, 'https://gbfs.spin.pm/api/gbfs/v2_3/nashville/gbfs')
# arg (720, 'https://gbfs.bcycle.com/bcycle_sanantonio/gbfs.json')
# arg (783, 'https://gbfs.spin.pm/api/gbfs/v2_3/raleigh/gbfs')
# arg (790, 'https://gbfs.spin.pm/api/gbfs/v2_3/santa%20monica/gbfs')
# arg (657, 'https://gbfs.bcycle.com/bcycle_houston/gbfs.json')
# argarg (727, 'https://gbfs.spin.pm/api/gbfs/v2_3/albuquerque/gbfs')
#  (685, 'https://mds.linkyour.city/gbfs/us_ca_oakland/gbfs.json')
# arg (699, 'https://gbfs.hopr.city/api/gbfs/35/')
# arg (797, 'https://gbfs.spin.pm/api/gbfs/v2_3/tampa/gbfs')
# arg (692, 'https://s3.amazonaws.com/lyft-lastmile-production-iad/lbs/den/gbfs.json')
# arg (804, 'https://gbfs.spin.pm/api/gbfs/v2_3/virginia_tech/gbfs')
# arg (706, 'https://pittsburgh.publicbikesystem.net/customer/gbfs/v2/gbfs.json')
# arg (713, 'https://gbfs.gorevel.com/gbfs/v2/miami/en/gbfs.json')
# arg (815, 'https://la-gbfs.getwheelsapp.com/gbfs.json')
# arg (822, 'https://weho-gbfs.getwheelsapp.com/gbfs.json')
# arg (811, 'https://gbfs.bcycle.com/bcycle_valentine/gbfs.json')
# arg (816, 'https://orlando-gbfs.getwheelsapp.com/gbfs.json')
# arg (817, 'https://san-gbfs.getwheelsapp.com/gbfs.json')
# arg (818, 'https://sm-gbfs.getwheelsapp.com/gbfs.json')
# 79 HTTPSConnectionPool(host='data.rollapi.com', port=443): Max retries exceeded with url: /v1/gbfs/kelowna/gbfs.json (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1002)')))
# arg (80, 'https://data.rollapi.com/v1/gbfs/ottawa/gbfs.json')
# 80 HTTPSConnectionPool(host='data.rollapi.com', port=443): Max retries exceeded with url: /v1/gbfs/ottawa/gbfs.json (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1002)')))
# arg (81, 'https://hamilton.socialbicycles.com/opendata/gbfs.json')
# arg (82, 'https://gbfs.spin.pm/api/gbfs/v2_3/edmonton/gbfs')
# arg (83, 'https://gbfs.spin.pm/api/gbfs/v2_3/kelowna/gbfs.json')

# %%
# !ls ~/code/closest-bike/raw-json  | tail
# Out:
# stations-82.json
# stations-83.json
# stations-86.json
# stations-87.json
# stations-88.json
# stations-89.json
# stations-9.json
# stations-90.json
# stations-91.json
# stations-99.json

# %%
v2_df = gbfs_df[gbfs_df['Auto-Discovery URL'].apply(lambda url: "v2" in url)]

# %%
feed = json.loads(open("%s/feeds-368.json" % base_dir).read())
feed
# Out:
# [{'name': 'system_information',
#   'url': 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_su/en/system_information.json'},
#  {'name': 'vehicle_types',
#   'url': 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_su/en/vehicle_types.json'},
#  {'name': 'station_information',
#   'url': 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_su/en/station_information.json'},
#  {'name': 'station_status',
#   'url': 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_su/en/station_status.json'},
#  {'name': 'free_bike_status',
#   'url': 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_su/en/free_bike_status.json'},
#  {'name': 'system_hours',
#   'url': 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_su/en/system_hours.json'},
#  {'name': 'system_regions',
#   'url': 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_su/en/system_regions.json'},
#  {'name': 'system_pricing_plans',
#   'url': 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_su/en/system_pricing_plans.json'}]

# %%
[obj for obj in feed if obj['name'] == 'station_information'][0]['url']
# Out:
# [{'name': 'station_information',
#   'url': 'https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_su/en/station_information.json'}]

# %%
def get_station_information_url(idx):
    feed = json.loads(open("%s/feeds-%d.json" % (base_dir, idx)).read())
    return [obj for obj in feed if obj['name'] == 'station_information'][0]['url']

# %%
url = "https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_su/en/station_information.json"

# %%
raw_data = json.loads(requests.get(url).text)
actual_data = raw_data['data']

# %%
def get_station_data(index, url):
    try:
        raw_data = json.loads(requests.get(url).text)
        actual_data = raw_data['data']['stations']
        open("%s/stations-%d.json" % (base_dir, index), "w").write(json.dumps(actual_data))
    except Exception as e:
        print(index, e)

# %%
def f(idx):
    url = get_station_information_url(idx)
    print(idx, url)
    get_station_data(idx, url)
with Pool(30) as p:
    #print(p.map(f, [1, 2, 3]))
    p.map(f, v2_df.index)
# Out:
# 29 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bj/en/station_information.json
# 53 https://salvador-br.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 66 https://data.lime.bike/api/partners/v2/gbfs/kelowna/station_information
# 106 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cy/en/station_information.json
# 43 https://data.lime.bike/api/partners/v2/gbfs/brussels/station_information
# 9 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ta/en/station_information.json
# 0 https://dubai.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 87 https://mds.bird.co/gbfs/v2/public/biel/station_information.json
# 59 https://mds.bird.co/gbfs/v2/public/calgary/station_information.json
# 99 https://data.lime.bike/api/partners/v2/gbfs/opfikon/station_information
# 116 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tw/en/station_information.json
# 111 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ts/en/station_information.json
# 126 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tt/en/station_information.json
# 121 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tm/en/station_information.json
# 131 https://mds.bird.co/gbfs/v2/public/ulm/station_information.json
# 146 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_sk/en/station_information.json
# 141 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_df/en/station_information.json
# 152 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dx/en/station_information.json
# 172 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_wn/en/station_information.json
# 162 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dj/en/station_information.json
# 187 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dv/en/station_information.json
# 157 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dd/en/station_information.json
# 192 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_wk/en/station_information.json
# 167 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_nm/en/station_information.json
# 177 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dc/en/station_information.json
# 214 https://barcelona-sp.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 254 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_fo/en/station_information.json
# 260 https://mds.bird.co/gbfs/v2/public/draguignan/station_information.json
# 229 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ei/en/station_information.json
# 265 https://mds.bird.co/gbfs/v2/public/marseille/station_information.json
# 100 https://data.lime.bike/api/partners/v2/gbfs/zug/station_information
# 88 https://mds.bird.co/gbfs/v2/public/bulle/station_information.json
# 132 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bf/en/station_information.json
# 67 https://data.lime.bike/api/partners/v2/gbfs/ottawa/station_information
# 261 https://mds.bird.co/gbfs/v2/public/epron/station_information.json
# 48 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bg/en/station_information.json
# 60 https://mds.bird.co/gbfs/v2/public/edmonton/station_information.json
# 127 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_vr/en/station_information.json
# 188 https://nitro.openvelo.org/aachen/velocity/v2/en/station_information.json
# 30 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ba/en/station_information.json
# 122 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ty/en/station_information.json
# 142 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_da/en/station_information.json
# 168 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_nn/en/station_information.json
# 117 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tq/en/station_information.json
# 270 https://mds.bird.co/gbfs/v2/public/vichy/station_information.json
# 232 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ls/en/station_information.json
# 112 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_th/en/station_information.json
# 10 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_si/en/station_information.json
# 193 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dw/en/station_information.json
# 163 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dk/en/station_information.json
# 178 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_rb/en/station_information.json
# 256 https://mds.bird.co/gbfs/v2/public/bordeaux/station_information.json
# 107 https://nicosia.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 147 https://data.lime.bike/api/partners/v2/gbfs/hamburg/station_information
# 158 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ef/en/station_information.json
# 153 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_re/en/station_information.json
# 266 https://mds.bird.co/gbfs/v2/public/millau/station_information.json
# 54215 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ea/en/station_information.json
#  https://saopaulo-br.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 4 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_al/en/station_information.json
# 89262 https://mds.bird.co/gbfs/v2/public/herouvillesaintclair/station_information.json
#  https://mds.bird.co/gbfs/v2/public/uster/station_information.json
# 82 https://gbfs.spin.pm/api/gbfs/v2_3/edmonton/station_information
# 101 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ch/en/station_information.json
# 61 https://mds.bird.co/gbfs/v2/public/ottawa/station_information.json
# 149 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_mz/en/station_information.json
# 267 https://mds.bird.co/gbfs/v2/public/montlucon/station_information.json
# 273 https://clermontferrand.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 49 https://recife.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 108 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_td/en/station_information.json
# 138 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ed/en/station_information.json
# 257 https://mds.bird.co/gbfs/v2/public/castres/station_information.json
# 128 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tv/en/station_information.json
# 235 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_sl/en/station_information.json
# 31 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bz/en/station_information.json
# 12 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_vt/en/station_information.json
# 210 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bs/en/station_information.json
# 123 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tg/en/station_information.json
# 159 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_er/en/station_information.json
# 169 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dl/en/station_information.json
# 164 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_lr/en/station_information.json
# 179 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dr/en/station_information.json
# 154 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_um/en/station_information.json
# 118 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ti/en/station_information.json
# 143113 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tl/en/station_information.json
#  https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_hg/en/station_information.json
# 90263 https://mds.bird.co/gbfs/v2/public/larochesuryon/station_information.json
#  https://mds.bird.co/gbfs/v2/public/winterthur/station_information.json
# 268 https://mds.bird.co/gbfs/v2/public/ouistreham/station_information.json
# 6 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_na/en/station_information.json
# 64 https://data.lime.bike/api/partners/v2/gbfs/calgary/station_information
# 189 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_vn/en/station_information.json
# 216 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bo/en/station_information.json
# 258 https://mds.bird.co/gbfs/v2/public/chalonsenchampagne/station_information.json
# 83264 https://mds.bird.co/gbfs/v2/public/laval/station_information.json
#  https://gbfs.spin.pm/api/gbfs/v2_3/kelowna/station_information
# 150 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dg/en/station_information.json
# 91 https://mds.bird.co/gbfs/v2/public/zurich/station_information.json
# 104 https://santiagodc.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 56 https://saguenay.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 109139 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_eb/en/station_information.json
#  https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_te/en/station_information.json
# 32 https://mds.bird.co/gbfs/v2/public/antwerp/station_information.json
# 236 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_el/en/station_information.json
# 165 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_le/en/station_information.json
# 13 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_wr/en/station_information.json
# 211 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ey/en/station_information.json
# 160 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ff/en/station_information.json
# 155 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_sn/en/station_information.json
# 114 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tz/en/station_information.json
# 288 https://data.lime.bike/api/partners/v2/gbfs/marseille/station_information
# 144 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_kg/en/station_information.json
# 50 https://portoalegre.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 269 https://mds.bird.co/gbfs/v2/public/sarreguemines/station_information.json
# 124 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cz/en/station_information.json
# 65 https://data.lime.bike/api/partners/v2/gbfs/edmonton/station_information
# 180 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ds/en/station_information.json
# 129 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ac/en/station_information.json
# 321 https://gbfs.beryl.cc/v2_2/Greater_Manchester/station_information.json
# 259 https://mds.bird.co/gbfs/v2/public/dieppe/station_information.json
# 119 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tj/en/station_information.json
# 86 https://mds.bird.co/gbfs/v2/public/basel/station_information.json
# 7 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ka/en/station_information.json
# 331 https://gbfs.beryl.cc/v2_2/Watford/station_information.json
# 365 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ub/en/station_information.json
# 217 https://mds.bird.co/gbfs/v2/public/madrid/station_information.json
# 370 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_gd/en/station_information.json
# 190 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_gh/en/station_information.json
# 289 https://data.lime.bike/api/partners/v2/gbfs/paris/station_information
# 57 https://quebec.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 151 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_mr/en/station_information.json
# 375 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bc/en/station_information.json
# 380 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_vu/en/station_information.json
# 385 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_hr/en/station_information.json
# 391 https://mds.bird.co/gbfs/v2/public/tel-aviv/station_information.json
# 110 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tf/en/station_information.json
# 414 https://gbfs.helbiz.com/v2.2/ferrara/station_information.json
# 166 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_li/en/station_information.json
# 161 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ng/en/station_information.json
# 212 https://acoruna.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 238 https://valladolid.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 28 https://aruba.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 156 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bn/en/station_information.json
# 115 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tk/en/station_information.json
# 51 https://riodejaneiro-br.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 145 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_fg/en/station_information.json
# 125 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tx/en/station_information.json
# 105 https://bogota.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 322 https://gbfs.beryl.cc/v2_2/Hereford/station_information.json
# 332 https://gbfs.beryl.cc/v2_2/West_Midlands/station_information.json
# 218 https://mds.bird.co/gbfs/v2/public/zaragoza/station_information.json
# 8 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_la/en/station_information.json
# 181 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dh/en/station_information.json
# 419 https://gbfs.helbiz.com/v2.2/h-farm/station_information.json
# 120 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_to/en/station_information.json
# 318 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bu/en/station_information.json
# 366 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ku/en/station_information.json
# 381 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_zd/en/station_information.json
# 376 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cs/en/station_information.json
# 424 https://gbfs.helbiz.com/v2.2/parma/station_information.json
# 323 https://gbfs.beryl.cc/v2_2/Hertsmere/station_information.json
# 333 https://gbfs.beryl.cc/v2_2/Wool/station_information.json
# 429 https://gbfs.helbiz.com/v2.2/rome/station_information.json
# 371 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ig/en/station_information.json
# 191 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_wd/en/station_information.json
# 499 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_bp/en/station_information.json
# 509 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pv/en/station_information.json
# 524 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_dp/en/station_information.json
# 386 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_br/en/station_information.json
# 534 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pr/en/station_information.json
# 539 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_vw/en/station_information.json
# 544 https://mds.bird.co/gbfs/v2/public/cascais/station_information.json
# 552 https://sibiu.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 562 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ce/en/station_information.json
# 324 https://gbfs.beryl.cc/v2_2/Isle_of_Wight/station_information.json
# 567 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cl/en/station_information.json
# 334 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_eu/en/station_information.json
# 572 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_nk/en/station_information.json
# 586 https://mds.bird.co/gbfs/v2/public/alexandria/station_information.json
# 415 https://gbfs.helbiz.com/v2.2/firenze/station_information.json
# 425 https://gbfs.helbiz.com/v2.2/pescara/station_information.json
# 420 https://gbfs.helbiz.com/v2.2/latina/station_information.json
# 58 https://toronto-us.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 592 https://mds.bird.co/gbfs/v2/public/columbus/station_information.json
# 431 https://data.lime.bike/api/partners/v2/gbfs/rome/station_information
# 597 https://mds.bird.co/gbfs/v2/public/indianapolis/station_information.json
# 602 https://mds.bird.co/gbfs/v2/public/new-york/station_information.json
# 367 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_uu/en/station_information.json
# 319 https://gbfs.beryl.cc/v2_2/BCP/station_information.json
# 382 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_sg/en/station_information.json
# 377 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_sb/en/station_information.json
# 607 https://mds.bird.co/gbfs/v2/public/washington-dc/station_information.json
# 372 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_kc/en/station_information.json
# 640 https://gbfs.helbiz.com/v2.2/jacksonville/station_information.json
# 645 https://gbfs.helbiz.com/v2.2/richmond/station_information.json
# 545 https://mds.bird.co/gbfs/v2/public/lisbon/station_information.json
# 325 https://gbfs.beryl.cc/v2_2/London/station_information.json
# 500 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pd/en/station_information.json
# 663 https://data.lime.bike/api/partners/v2/gbfs/arlington/station_information
# 587 https://mds.bird.co/gbfs/v2/public/arlingtonco/station_information.json
# 668 https://data.lime.bike/api/partners/v2/gbfs/grand_rapids/station_information
# 416 https://gbfs.helbiz.com/v2.2/fiumicino/station_information.json
# 593 https://mds.bird.co/gbfs/v2/public/culver-city/station_information.json
# 437 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ib/en/station_information.json
# 598 https://mds.bird.co/gbfs/v2/public/kansas-city/station_information.json
# 421 https://gbfs.helbiz.com/v2.2/modena/station_information.json
# 426 https://gbfs.helbiz.com/v2.2/pisa/station_information.json
# 603 https://mds.bird.co/gbfs/v2/public/portland/station_information.json
# 320 https://gbfs.beryl.cc/v2_2/Cornwall/station_information.json
# 387 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_se/en/station_information.json
# 535 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ap/en/station_information.json
# 553 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_rt/en/station_information.json
# 540 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pl/en/station_information.json
# 563 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cd/en/station_information.json
# 568 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cf/en/station_information.json
# 573 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_nu/en/station_information.json
# 335 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tb/en/station_information.json
# 636 https://gbfs.helbiz.com/v2.2/alexandria/station_information.json
# 646 https://gbfs.helbiz.com/v2.2/sacramento/station_information.json
# 641 https://gbfs.helbiz.com/v2.2/miami/station_information.json
# 368 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_su/en/station_information.json
# 673 https://data.lime.bike/api/partners/v2/gbfs/providence/station_information
# 664 https://data.lime.bike/api/partners/v2/gbfs/chicago/station_information
# 588 https://mds.bird.co/gbfs/v2/public/baltimore/station_information.json
# 689 https://louisville.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 669 https://data.lime.bike/api/partners/v2/gbfs/louisville/station_information
# 383 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ol/en/station_information.json
# 378 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_gt/en/station_information.json
# 417 https://gbfs.helbiz.com/v2.2/frosinone/station_information.json
# 599 https://mds.bird.co/gbfs/v2/public/los-angeles/station_information.json
# 422 https://gbfs.helbiz.com/v2.2/napoli/station_information.json
# 549604 https://mds.bird.co/gbfs/v2/public/san-francisco/station_information.json
#  https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_rd/en/station_information.json
# 594 https://mds.bird.co/gbfs/v2/public/detroit/station_information.json
# 427 https://gbfs.helbiz.com/v2.2/reggio/station_information.json
# 715 https://gbfs.gorevel.com/gbfs/v2/oakland/en/station_information.json
# 373 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ma/en/station_information.json
# 501 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_jp/en/station_information.json
# 637 https://gbfs.helbiz.com/v2.2/arlington/station_information.json
# 447 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_lv/en/station_information.json
# 647 https://gbfs.helbiz.com/v2.2/santabarbara/station_information.json
# 727 https://gbfs.spin.pm/api/gbfs/v2_3/albuquerque/station_information
# 590 https://mds.bird.co/gbfs/v2/public/chicago/station_information.json
# 665 https://data.lime.bike/api/partners/v2/gbfs/cleveland/station_information
# 732 https://gbfs.spin.pm/api/gbfs/v2_3/austin/station_information
# 642 https://gbfs.helbiz.com/v2.2/miamilakes/station_information.json
# 674 https://data.lime.bike/api/partners/v2/gbfs/san_francisco/station_information
# 554 https://santana.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 541 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_pm/en/station_information.json
# 670 https://data.lime.bike/api/partners/v2/gbfs/new_york/station_information
# 564 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cn/en/station_information.json
# 418 https://gbfs.helbiz.com/v2.2/genova/station_information.json
# 600 https://mds.bird.co/gbfs/v2/public/louisville/station_information.json
# 423 https://gbfs.helbiz.com/v2.2/palermo/station_information.json
# 574 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_uv/en/station_information.json
# 737 https://gbfs.spin.pm/api/gbfs/v2_3/chicago_territory/station_information
# 569 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_as/en/station_information.json
# 428 https://gbfs.helbiz.com/v2.2/rho/station_information.json
# 595 https://mds.bird.co/gbfs/v2/public/durham/station_information.json
# 605 https://mds.bird.co/gbfs/v2/public/st-louis/station_information.json
# 701 https://detroit-us.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 369 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_em/en/station_information.json
# 638 https://gbfs.helbiz.com/v2.2/durham/station_information.json
# 716 https://gbfs.gorevel.com/gbfs/v2/sanfrancisco/en/station_information.json
# 384 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cj/en/station_information.json
# 379 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cg/en/station_information.json
# 550 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_nw/en/station_information.json
# 648 https://gbfs.helbiz.com/v2.2/washington/station_information.json
# 374 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_cm/en/station_information.json
# 728 https://gbfs.spin.pm/api/gbfs/v2_3/alexandria/station_information
# 733 https://gbfs.spin.pm/api/gbfs/v2_3/baltimore/station_information
# 643 https://gbfs.helbiz.com/v2.2/oklahoma/station_information.json
# 591671 https://data.lime.bike/api/partners/v2/gbfs/oakland/station_information
#  https://mds.bird.co/gbfs/v2/public/cleveland/station_information.json
# 666 https://data.lime.bike/api/partners/v2/gbfs/colorado_springs/station_information
# 675 https://data.lime.bike/api/partners/v2/gbfs/san_jose/station_information
# 601 https://mds.bird.co/gbfs/v2/public/miami/station_information.json
# 738 https://gbfs.spin.pm/api/gbfs/v2_3/cleveland/station_information
# 742 https://gbfs.spin.pm/api/gbfs/v2_3/denver/station_information
# 747 https://gbfs.spin.pm/api/gbfs/v2_3/fort_collins/station_information
# 596 https://mds.bird.co/gbfs/v2/public/fairfax/station_information.json
# 752 https://gbfs.spin.pm/api/gbfs/v2_3/greenville/station_information
# 757 https://gbfs.spin.pm/api/gbfs/v2_3/knoxville/station_information
# 606 https://mds.bird.co/gbfs/v2/public/tempe/station_information.json
# 448 https://monaco.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 762 https://gbfs.spin.pm/api/gbfs/v2_3/louisville/station_information
# 542 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_zy/en/station_information.json
# 767 https://gbfs.spin.pm/api/gbfs/v2_3/minneapolis/station_information
# 717 https://gbfs.gorevel.com/gbfs/v2/washingtondc/en/station_information.json
# 639 https://gbfs.helbiz.com/v2.2/flint/station_information.json
# 729 https://gbfs.spin.pm/api/gbfs/v2_3/ann_arbor/station_information
# 570 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_ak/en/station_information.json
# 581 https://chattanooga.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 734 https://gbfs.spin.pm/api/gbfs/v2_3/boise/station_information
# 649 https://gbfs.helbiz.com/v2.2/waterloo/station_information.json
# 644 https://gbfs.helbiz.com/v2.2/orlando/station_information.json
# 772 https://gbfs.spin.pm/api/gbfs/v2_3/oakland_university/station_information
# 672 https://data.lime.bike/api/partners/v2/gbfs/portland/station_information
# 667 https://data.lime.bike/api/partners/v2/gbfs/detroit/station_information
# 777 https://gbfs.spin.pm/api/gbfs/v2_3/phoenix/station_information
# 739 https://gbfs.spin.pm/api/gbfs/v2_3/columbus/station_information
# 676 https://data.lime.bike/api/partners/v2/gbfs/seattle/station_information
# 782 https://gbfs.spin.pm/api/gbfs/v2_3/purdue_university/station_information
# 743 https://gbfs.spin.pm/api/gbfs/v2_3/detroit/station_information
# 748 https://gbfs.spin.pm/api/gbfs/v2_3/fort_pierce/station_information
# 706 https://pittsburgh.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 787 https://gbfs.spin.pm/api/gbfs/v2_3/san_diego/station_information
# 753 https://gbfs.spin.pm/api/gbfs/v2_3/isla_vista/station_information
# 758 https://gbfs.spin.pm/api/gbfs/v2_3/lexington/station_information
# 792 https://gbfs.spin.pm/api/gbfs/v2_3/south_miami/station_information
# 763 https://gbfs.spin.pm/api/gbfs/v2_3/memphis/station_information
# 768 https://gbfs.spin.pm/api/gbfs/v2_3/montgomery_county/station_information
# 723 https://stonybrook.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 735797 https://gbfs.spin.pm/api/gbfs/v2_3/tampa/station_information
# 802 https://gbfs.spin.pm/api/gbfs/v2_3/university_of_central_florida/station_information
# 551 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_rs/en/station_information.json
#  https://gbfs.spin.pm/api/gbfs/v2_3/brookline/station_information
# 730 https://gbfs.spin.pm/api/gbfs/v2_3/asbury_park/station_information
# 807 https://gbfs.spin.pm/api/gbfs/v2_3/wichita/station_information
# 773 https://gbfs.spin.pm/api/gbfs/v2_3/ohio_state/station_information
# 778 https://gbfs.spin.pm/api/gbfs/v2_3/pittsburgh/station_information
# 740 https://gbfs.spin.pm/api/gbfs/v2_3/coral_gables/station_information
# 677 https://data.lime.bike/api/partners/v2/gbfs/washington_dc/station_information
# 783 https://gbfs.spin.pm/api/gbfs/v2_3/raleigh/station_information
# 749 https://gbfs.spin.pm/api/gbfs/v2_3/gainesville/station_information
# 744 https://gbfs.spin.pm/api/gbfs/v2_3/duke/station_information
# 543754 https://gbfs.spin.pm/api/gbfs/v2_3/jacksonville/station_information
#  https://mds.bird.co/gbfs/v2/public/braga/station_information.json
# 788 https://gbfs.spin.pm/api/gbfs/v2_3/san_francisco/station_information
# 759 https://gbfs.spin.pm/api/gbfs/v2_3/lincoln/station_information
# 793 https://gbfs.spin.pm/api/gbfs/v2_3/st_george/station_information
# 585 https://hon.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 764 https://gbfs.spin.pm/api/gbfs/v2_3/mesa/station_information
# 571 https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_tr/en/station_information.json
# 769 https://gbfs.spin.pm/api/gbfs/v2_3/nashville/station_information
# 808774 https://gbfs.spin.pm/api/gbfs/v2_3/omaha/station_information
#  https://gbfs.spin.pm/api/gbfs/v2_3/winston_salem/station_information
# 736 https://gbfs.spin.pm/api/gbfs/v2_3/charlotte/station_information
# 803 https://gbfs.spin.pm/api/gbfs/v2_3/university_of_kentucky/station_information
# 798 https://gbfs.spin.pm/api/gbfs/v2_3/tempe/station_information
# 731 https://gbfs.spin.pm/api/gbfs/v2_3/atlanta/station_information
# 713 https://gbfs.gorevel.com/gbfs/v2/miami/en/station_information.json
# 741 https://gbfs.spin.pm/api/gbfs/v2_3/dayton/station_information
# 784 https://gbfs.spin.pm/api/gbfs/v2_3/salem/station_information
# 779 https://gbfs.spin.pm/api/gbfs/v2_3/portland/station_information
# 750 https://gbfs.spin.pm/api/gbfs/v2_3/garden_city/station_information
# 745 https://gbfs.spin.pm/api/gbfs/v2_3/durham/station_information
# 726 https://gbfs.spin.pm/api/gbfs/v2_3/akron/station_information
# 755 https://gbfs.spin.pm/api/gbfs/v2_3/jefferson_city/station_information
# 789 https://gbfs.spin.pm/api/gbfs/v2_3/san_marcos/station_information
# 794 https://gbfs.spin.pm/api/gbfs/v2_3/stillwater/station_information
# 760 https://gbfs.spin.pm/api/gbfs/v2_3/long_beach/station_information
# 765 https://gbfs.spin.pm/api/gbfs/v2_3/miami/station_information
# 770 https://gbfs.spin.pm/api/gbfs/v2_3/nicholls_state/station_information
# 804 https://gbfs.spin.pm/api/gbfs/v2_3/virginia_tech/station_information
# 810 https://tucson-us.publicbikesystem.net/customer/gbfs/v2/en/station_information
# 775 https://gbfs.spin.pm/api/gbfs/v2_3/orem/station_information
# 799 https://gbfs.spin.pm/api/gbfs/v2_3/towson/station_information
# 780 https://gbfs.spin.pm/api/gbfs/v2_3/providence/station_information
# 714 https://gbfs.gorevel.com/gbfs/v2/newyork/en/station_information.json
# 751 https://gbfs.spin.pm/api/gbfs/v2_3/grand_rapids/station_information
# 785 https://gbfs.spin.pm/api/gbfs/v2_3/salt_lake_city/station_information
# 746 https://gbfs.spin.pm/api/gbfs/v2_3/fayetteville/station_information
# 756 https://gbfs.spin.pm/api/gbfs/v2_3/kansas_city/station_information
# 790 https://gbfs.spin.pm/api/gbfs/v2_3/santa%20monica/station_information
# 766 https://gbfs.spin.pm/api/gbfs/v2_3/michigan_state_university/station_information
# 761 https://gbfs.spin.pm/api/gbfs/v2_3/los_angeles/station_information
# 795 https://gbfs.spin.pm/api/gbfs/v2_3/st_louis/station_information
# 771 https://gbfs.spin.pm/api/gbfs/v2_3/nmsu/station_information
# 776800 https://gbfs.spin.pm/api/gbfs/v2_3/troy/station_information
#  https://gbfs.spin.pm/api/gbfs/v2_3/orlando/station_information
# 805 https://gbfs.spin.pm/api/gbfs/v2_3/washington_dc/station_information
# 781 https://gbfs.spin.pm/api/gbfs/v2_3/provo/station_information
# 786 https://gbfs.spin.pm/api/gbfs/v2_3/san_antonio/station_information
# 791 https://gbfs.spin.pm/api/gbfs/v2_3/seattle/station_information
# 796 https://gbfs.spin.pm/api/gbfs/v2_3/tallahassee/station_information
# 806 https://gbfs.spin.pm/api/gbfs/v2_3/white_center/station_information
# 801 https://gbfs.spin.pm/api/gbfs/v2_3/uc_san_diego/station_information
# 812 https://aspen-us.publicbikesystem.net/customer/gbfs/v2/en/station_information
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 7
#       4     get_station_data(idx, url)
#       5 with Pool(30) as p:
#       6     #print(p.map(f, [1, 2, 3]))
# ----> 7     p.map(f, v2_df.index)
#
# File ~/opt/anaconda3/envs/buckaroo-dev/lib/python3.11/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/opt/anaconda3/envs/buckaroo-dev/lib/python3.11/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File ~/opt/anaconda3/envs/buckaroo-dev/lib/python3.11/multiprocessing/pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File ~/opt/anaconda3/envs/buckaroo-dev/lib/python3.11/multiprocessing/pool.py:48, in mapstar(args)
#      47 def mapstar(args):
# ---> 48     return list(map(*args))
#
# Cell In[28], line 2, in f(idx)
#       1 def f(idx):
# ----> 2     url = get_station_information_url(idx)
#       3     print(idx, url)
#       4     get_station_data(idx, url)
#
# Cell In[19], line 3, in get_station_information_url(idx)
#       1 def get_station_information_url(idx):
#       2     feed = json.loads(open("%s/feeds-%d.json" % (base_dir, idx)).read())
# ----> 3     return [obj for obj in feed if obj['name'] == 'station_information'][0]['url']
#
# IndexError: list index out of range

# %%
# !ls ~/code/closest-bike/raw-json/station*  |wc -l
# Out:
#      379

# %%
pd.read_json("/Users/paddy/code/closest-bike/raw-json/stations-105.json")[:3]
# Out:
#    station_id                           name physical_configuration       lat  \
# 0           1  001 - Centro Comercial Andino                REGULAR  4.665803
# 1           2          002 - CL 65 con KR 10                REGULAR  4.650789
# 2           3          003 - CL 73 con KR 15                REGULAR  4.659926
#
#          lon  altitude                                 address  \
# 0 -74.052844       NaN  Calle 82 entre Carrera 11 y Carrera 12
# 1 -74.061453       0.0  Calle 65 entre Carrera 10 y Carrera 11
# 2 -74.060431       0.0  Calle 73 entre Carrera 13 y Carrera 15
#
#       cross_street  post_code  capacity  is_charging_station  \
# 0        EL RETIRO     1111.0        19                False
# 1  CHAPINERO NORTE     1111.0         7                False
# 2       LA CABRERA     1111.0         7                False
#
#                           rental_methods  is_virtual_station groups  \
# 0  [KEY, TRANSITCARD, CREDITCARD, PHONE]               False     []
# 1  [KEY, TRANSITCARD, CREDITCARD, PHONE]               False     []
# 2  [KEY, TRANSITCARD, CREDITCARD, PHONE]               False     []
#
#    nearby_distance _bluetooth_id  _ride_code_support rental_uris obcn  \
# 0             1000          2f73                True          {}  NaN
# 1             1000          e8e7                True          {}
# 2             1000          894c                True          {}
#
#    is_valet_station
# 0               NaN
# 1               NaN
# 2               NaN

# %%
print("base_dir", base_dir)
# Out:
# base_dir /Users/paddy/code/closest-bike/raw-json

# %%
station_f_list = [f for f in os.listdir(base_dir)if "stations" in f]
dfs = [pd.read_json(base_dir + "/" + f)  for f in station_f_list]

# %%
all_dfs = pd.concat(dfs)

# %%
all_dfs['capacity'].sum()
# Out:
# 191288.0

# %%
BuckarooWidget(all_dfs)
# Out:
# BuckarooWidget(commandConfig={'argspecs': {'dropcol': [None], 'to_datetime': [None], 'safeint': [None], 'filln…

# %%
# !ls ~/code/closest-bike/raw-json  | tail

# %%
actual_data['stations'][:3]
# Out:
# [{'station_id': '6364500',
#   'name': 'Manor Park Residences',
#   'short_name': '8779',
#   'lat': 51.237795,
#   'lon': -0.61335,
#   'region_id': '485',
#   'rental_uris': {'android': 'https://app.nextbike.net/station?id=6364500',
#    'ios': 'https://app.nextbike.net/station?id=6364500',
#    'web': 'https://nxtb.it/p/6364500'},
#   'is_virtual_station': False,
#   'capacity': 14},
#  {'station_id': '6364524',
#   'name': 'Surrey Technology Centre',
#   'short_name': '8780',
#   'lat': 51.239579,
#   'lon': -0.611192,
#   'region_id': '485',
#   'rental_uris': {'android': 'https://app.nextbike.net/station?id=6364524',
#    'ios': 'https://app.nextbike.net/station?id=6364524',
#    'web': 'https://nxtb.it/p/6364524'},
#   'is_virtual_station': False,
#   'capacity': 14},
#  {'station_id': '6364547',
#   'name': 'VSM Building',
#   'short_name': '8781',
#   'lat': 51.236866,
#   'lon': -0.609129,
#   'region_id': '485',
#   'rental_uris': {'android': 'https://app.nextbike.net/station?id=6364547',
#    'ios': 'https://app.nextbike.net/station?id=6364547',
#    'web': 'https://nxtb.it/p/6364547'},
#   'is_virtual_station': False,
#   'capacity': 6}]

# %%
for idx in v2_df.index:
    try:
        url = get_station_information_url(idx)

# %%
v2_df.index[:10]
# Out:
# Int64Index([0, 4, 6, 7, 8, 9, 10, 12, 13, 28], dtype='int64')

# %%
for idx, url  in enumerate(gbfs_df['Auto-Discovery URL']):
    print(idx)
    get_system_data(idx, url)

# %%
def pull_auto_discovery(index_num, url):
    system_data = json.loads(requests.get(url).text)
